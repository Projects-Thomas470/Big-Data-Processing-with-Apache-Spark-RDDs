# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.4.0.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.0-py2.py3-none-any.whl size=311317130 sha256=760df90317b1ce610236386d69b01d02523789152c91dcb520804833b9fa84f9
#   Stored in directory: /root/.cache/pip/wheels/7b/1b/4b/3363a1d04368e7ff0d408e57ff57966fcdf00583774e761327
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.0

# %%
# !wget https://jpbarddal.github.io/assets/data/bigdata/transactions_amostra.csv.zip
# !unzip transactions_amostra.csv.zip
# Out:
# --2023-05-20 03:24:41--  https://jpbarddal.github.io/assets/data/bigdata/transactions_amostra.csv.zip
# Resolving jpbarddal.github.io (jpbarddal.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to jpbarddal.github.io (jpbarddal.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47513871 (45M) [application/zip]
# Saving to: ‘transactions_amostra.csv.zip’
#
# transactions_amostr 100%[===================>]  45.31M   201MB/s    in 0.2s
#
# 2023-05-20 03:24:42 (201 MB/s) - ‘transactions_amostra.csv.zip’ saved [47513871/47513871]
#
# Archive:  transactions_amostra.csv.zip
#   inflating: transactions_amostra.csv
#   inflating: __MACOSX/._transactions_amostra.csv

# %%
from pyspark.sql import SparkSession

# Inicializa o Spark
spark = SparkSession.builder\
    .master('local[*]')\
    .appName("")\
    .getOrCreate()
    
sc = spark.sparkContext

# Carrega o conjunto de dados a partir do arquivo CSV
dataset = sc.textFile("transactions_amostra.csv")

# %%
# Printando as colunas

columns = dataset.take(1)[0].split(";")
print("Colunas do dataset:")
for column in columns:
    print(column)
# Out:
# Colunas do dataset:
# country_or_area
# year
# comm_code
# commodity
# flow
# trade_usd
# weight_kg
# quantity_name
# quantity
# category

# %% [markdown]
# #Problema 1: O número de transações envolvendo o Brasil

# %%
# Filtra as transações que envolvem o Brasil
transacoes_brasil = dataset.filter(lambda linha: "Brazil" in linha)

# Converte para um PairRDD com uma chave constante
transacoes_brasil_com_chave = transacoes_brasil.map(lambda linha: ("brasil", 1))

# Calcula o total de transações envolvendo o Brasil
total_transacoes_brasil = transacoes_brasil_com_chave.reduceByKey(lambda a, b: a + b)

# Recupera a contagem
contagem = total_transacoes_brasil.collect()[0][1]

print("Total de transações envolvendo o Brasil:", contagem)
# Out:
# Total de transações envolvendo o Brasil: 27693

# %% [markdown]
# #Problema 2: O número de transações por tipo de fluxo e ano

# %%
# Mapeia as transações para o par ((tipo de fluxo, ano), 1)
transacoes_por_fluxo_ano = dataset.map(lambda linha: ((linha.split(";")[4], linha.split(";")[1]), 1)) \
    .reduceByKey(lambda a, b: a + b)

# Itera sobre os resultados e imprime o tipo de fluxo, ano e contagem de transações
for fluxo_ano, contagem in transacoes_por_fluxo_ano.collect():
    print("Tipo de fluxo e ano:", fluxo_ano, contagem)
# Out:
# Tipo de fluxo e ano: ('Import', '2013') 30689
# Tipo de fluxo e ano: ('Import', '2010') 31435
# Tipo de fluxo e ano: ('Import', '2003') 29997
# Tipo de fluxo e ano: ('Export', '2015') 17756
# Tipo de fluxo e ano: ('Export', '2014') 17984
# Tipo de fluxo e ano: ('Import', '2012') 29987
# Tipo de fluxo e ano: ('Import', '2014') 29723
# Tipo de fluxo e ano: ('Import', '1995') 19375
# Tipo de fluxo e ano: ('Export', '2012') 17863
# Tipo de fluxo e ano: ('Export', '2013') 18063
# Tipo de fluxo e ano: ('Re-Export', '2003') 1706
# Tipo de fluxo e ano: ('Re-Export', '2013') 2225
# Tipo de fluxo e ano: ('Re-Import', '2005') 1323
# Tipo de fluxo e ano: ('Re-Export', '1995') 1132
# Tipo de fluxo e ano: ('Re-Export', '1990') 518
# Tipo de fluxo e ano: ('flow', 'year') 1
# Tipo de fluxo e ano: ('Export', '2008') 17445
# Tipo de fluxo e ano: ('Import', '2008') 29883
# Tipo de fluxo e ano: ('Import', '2005') 31124
# Tipo de fluxo e ano: ('Export', '2009') 17825
# Tipo de fluxo e ano: ('Export', '1989') 3547
# Tipo de fluxo e ano: ('Re-Import', '2011') 1456
# Tipo de fluxo e ano: ('Re-Import', '2012') 1418
# Tipo de fluxo e ano: ('Re-Import', '2014') 1457
# Tipo de fluxo e ano: ('Re-Import', '2003') 1242
# Tipo de fluxo e ano: ('Re-Export', '1992') 764
# Tipo de fluxo e ano: ('Export', '2016') 15260
# Tipo de fluxo e ano: ('Export', '2011') 17706
# Tipo de fluxo e ano: ('Import', '1994') 15718
# Tipo de fluxo e ano: ('Export', '2004') 17944
# Tipo de fluxo e ano: ('Export', '2003') 17484
# Tipo de fluxo e ano: ('Import', '2015') 28834
# Tipo de fluxo e ano: ('Import', '1990') 4866
# Tipo de fluxo e ano: ('Export', '1993') 7766
# Tipo de fluxo e ano: ('Import', '2002') 28956
# Tipo de fluxo e ano: ('Export', '1994') 10262
# Tipo de fluxo e ano: ('Re-Export', '2002') 1554
# Tipo de fluxo e ano: ('Re-Export', '2011') 2411
# Tipo de fluxo e ano: ('Re-Export', '2014') 2806
# Tipo de fluxo e ano: ('Export', '2007') 17445
# Tipo de fluxo e ano: ('Export', '1995') 11547
# Tipo de fluxo e ano: ('Re-Import', '2006') 1501
# Tipo de fluxo e ano: ('Re-Export', '1994') 1079
# Tipo de fluxo e ano: ('Re-Export', '2007') 2316
# Tipo de fluxo e ano: ('Re-Import', '2000') 952
# Tipo de fluxo e ano: ('Re-Export', '2015') 2646
# Tipo de fluxo e ano: ('Re-Import', '2001') 1001
# Tipo de fluxo e ano: ('Export', '1996') 12732
# Tipo de fluxo e ano: ('Import', '1998') 24881
# Tipo de fluxo e ano: ('Import', '2009') 31001
# Tipo de fluxo e ano: ('Import', '1997') 23685
# Tipo de fluxo e ano: ('Import', '2001') 29242
# Tipo de fluxo e ano: ('Export', '1997') 13541
# Tipo de fluxo e ano: ('Import', '1999') 26147
# Tipo de fluxo e ano: ('Import', '2006') 32301
# Tipo de fluxo e ano: ('Export', '2006') 18585
# Tipo de fluxo e ano: ('Re-Export', '2000') 2104
# Tipo de fluxo e ano: ('Import', '1988') 2139
# Tipo de fluxo e ano: ('Re-Import', '2004') 1197
# Tipo de fluxo e ano: ('Re-Export', '2009') 2528
# Tipo de fluxo e ano: ('Re-Import', '2002') 1119
# Tipo de fluxo e ano: ('Re-Import', '2013') 1431
# Tipo de fluxo e ano: ('Re-Import', '2015') 1479
# Tipo de fluxo e ano: ('Re-Export', '1998') 1519
# Tipo de fluxo e ano: ('Re-Import', '2010') 1278
# Tipo de fluxo e ano: ('Re-Export', '2001') 1874
# Tipo de fluxo e ano: ('Re-Export', '2008') 2323
# Tipo de fluxo e ano: ('Re-Export', '1988') 372
# Tipo de fluxo e ano: ('Re-Export', '1989') 482
# Tipo de fluxo e ano: ('Import', '2016') 22583
# Tipo de fluxo e ano: ('Export', '1991') 4499
# Tipo de fluxo e ano: ('Re-Import', '2009') 1385
# Tipo de fluxo e ano: ('Export', '2002') 16735
# Tipo de fluxo e ano: ('Import', '1993') 12140
# Tipo de fluxo e ano: ('Import', '2011') 31301
# Tipo de fluxo e ano: ('Import', '2004') 30945
# Tipo de fluxo e ano: ('Import', '2007') 31840
# Tipo de fluxo e ano: ('Export', '2010') 17849
# Tipo de fluxo e ano: ('Re-Import', '2008') 1366
# Tipo de fluxo e ano: ('Re-Export', '2016') 2298
# Tipo de fluxo e ano: ('Re-Export', '2004') 1877
# Tipo de fluxo e ano: ('Re-Export', '2010') 2348
# Tipo de fluxo e ano: ('Import', '1991') 6185
# Tipo de fluxo e ano: ('Export', '1990') 3700
# Tipo de fluxo e ano: ('Re-Export', '2012') 2345
# Tipo de fluxo e ano: ('Re-Export', '1993') 973
# Tipo de fluxo e ano: ('Re-Export', '1991') 652
# Tipo de fluxo e ano: ('Re-Export', '2006') 2431
# Tipo de fluxo e ano: ('Export', '1998') 14131
# Tipo de fluxo e ano: ('Export', '2005') 17993
# Tipo de fluxo e ano: ('Import', '1996') 21311
# Tipo de fluxo e ano: ('Export', '2000') 16855
# Tipo de fluxo e ano: ('Import', '1992') 9305
# Tipo de fluxo e ano: ('Export', '2001') 16759
# Tipo de fluxo e ano: ('Export', '1992') 6226
# Tipo de fluxo e ano: ('Re-Export', '1997') 1605
# Tipo de fluxo e ano: ('Export', '1988') 1772
# Tipo de fluxo e ano: ('Import', '1989') 4370
# Tipo de fluxo e ano: ('Import', '2000') 28884
# Tipo de fluxo e ano: ('Export', '1999') 15018
# Tipo de fluxo e ano: ('Re-Export', '1999') 2046
# Tipo de fluxo e ano: ('Re-Import', '2016') 939
# Tipo de fluxo e ano: ('Re-Export', '2005') 2379
# Tipo de fluxo e ano: ('Re-Import', '2007') 1328
# Tipo de fluxo e ano: ('Re-Export', '1996') 1211

# %% [markdown]
# # Problema 3: A média dos valores das commodities por ano

# %%
# Filtra as linhas que possuem um valor numérico válido na coluna de valores de commodities
valores_commodities = dataset.filter(lambda linha: linha.split(";")[5].replace(".", "").isdigit()) \
    .map(lambda linha: (linha.split(";")[1], float(linha.split(";")[5])))

# Calcula a soma e contagem dos valores das commodities por ano usando a função aggregateByKey
valores_commodities_por_ano = valores_commodities.aggregateByKey((0.0, 0),
                                                                  lambda acumulador, valor: (acumulador[0] + valor, acumulador[1] + 1),
                                                                  lambda acumulador1, acumulador2: (acumulador1[0] + acumulador2[0], acumulador1[1] + acumulador2[1]))

# Calcula a média dos valores das commodities por ano usando a função mapValues
media_valores_por_ano = valores_commodities_por_ano.mapValues(lambda acumulador: acumulador[0] / acumulador[1])

# Itera sobre os resultados e imprime o valor médio da commodity para cada ano
for ano, media in media_valores_por_ano.collect():
    print("Valor médio da commodity para o ano", ano, ":", media)
# Out:
# Valor médio da commodity para o ano 2016 : 29418327.57526777
# Valor médio da commodity para o ano 2011 : 33559943.50890797
# Valor médio da commodity para o ano 2003 : 13028917.611334749
# Valor médio da commodity para o ano 1993 : 10353959.855309162
# Valor médio da commodity para o ano 2007 : 23710673.174875777
# Valor médio da commodity para o ano 2014 : 46120404.41345007
# Valor médio da commodity para o ano 2012 : 39028921.881444596
# Valor médio da commodity para o ano 1995 : 12286454.103356835
# Valor médio da commodity para o ano 2006 : 21175872.541099638
# Valor médio da commodity para o ano 1997 : 9549881.214776853
# Valor médio da commodity para o ano 2005 : 18673099.052178193
# Valor médio da commodity para o ano 1999 : 9561516.927263891
# Valor médio da commodity para o ano 1992 : 9402960.863025468
# Valor médio da commodity para o ano 1994 : 11350325.049077941
# Valor médio da commodity para o ano 2004 : 15388487.793083541
# Valor médio da commodity para o ano 1991 : 13069223.85515173
# Valor médio da commodity para o ano 2002 : 12653310.252481185
# Valor médio da commodity para o ano 2008 : 33285215.353921242
# Valor médio da commodity para o ano 2001 : 9942220.288239626
# Valor médio da commodity para o ano 2013 : 33061151.28882995
# Valor médio da commodity para o ano 2010 : 26909386.074333776
# Valor médio da commodity para o ano 2015 : 31115574.884196
# Valor médio da commodity para o ano 1990 : 11724265.86778952
# Valor médio da commodity para o ano 1996 : 11945524.161286663
# Valor médio da commodity para o ano 1998 : 10175610.459598826
# Valor médio da commodity para o ano 2009 : 25068409.504465386
# Valor médio da commodity para o ano 2000 : 13547613.067035558
# Valor médio da commodity para o ano 1988 : 18642970.55638571
# Valor médio da commodity para o ano 1989 : 11263871.329920229

# %% [markdown]
# # Problema 4: O preço médio das commodities por tipo de unidade, ano e categoria no fluxo de exportação no Brasil

# %%
# Filtra as transações que envolvem o Brasil e estão no fluxo de exportação
export_flow_brazil = dataset.filter(lambda line: "Brazil" in line and line.split(";")[4] == "Export")

# Mapeia as linhas para obter o tipo de unidade, ano, categoria e preço da commodity
commodity_price_per_unit_type = export_flow_brazil.map(lambda line: ((line.split(";")[7], line.split(";")[1], line.split(";")[8]), float(line.split(";")[5])))

# Calcula a soma e contagem dos preços das commodities por tipo de unidade, ano e categoria usando a função aggregateByKey
commodity_price_per_unit_type_category = commodity_price_per_unit_type.aggregateByKey((0.0, 0),
                                                                                      lambda acumulador, valor: (acumulador[0] + valor, acumulador[1] + 1),
                                                                                      lambda acumulador1, acumulador2: (acumulador1[0] + acumulador2[0], acumulador1[1] + acumulador2[1]))

# Calcula o preço médio das commodities por tipo de unidade, ano e categoria usando a função mapValues
average_price_per_unit_type_category = commodity_price_per_unit_type_category.mapValues(lambda acumulador: acumulador[0] / acumulador[1])

print("Preço médio das commodities por tipo de unidade, ano e categoria no fluxo de exportação no Brasil:")

# Coleta os resultados e imprime cada elemento
result = average_price_per_unit_type_category.collect()
for element in result:
    print(element)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# (('Weight in kilograms', '1993', '105817.0'), 1053372.0)
# (('Weight in kilograms', '2006', '24211.0'), 137098.0)
# (('Weight in kilograms', '1995', '26000.0'), 9949.0)
# (('Weight in kilograms', '2004', '23984005.0'), 84859819.0)
# (('Weight in kilograms', '2005', '7269.0'), 45357.0)
# (('Weight in kilograms', '1997', '669.0'), 10931.0)
# (('Weight in kilograms', '2005', '11682.0'), 7031.0)
# (('Weight in kilograms', '1992', '105000.0'), 6461.0)
# (('Weight in kilograms', '2006', '9612.0'), 62827.0)
# (('Number of items', '2012', '201.0'), 11594.0)
# (('Weight in kilograms', '1997', '57824.0'), 653383.0)
# (('Weight in kilograms', '1991', '201.0'), 12320.0)
# (('Weight in kilograms', '1999', '27223.0'), 150872.0)
# (('Weight in kilograms', '2000', '8441773.0'), 506553.0)
# (('Weight in kilograms', '2014', '1341250.0'), 1183625.0)
# (('Weight in kilograms', '1998', '2321912.0'), 29202302.0)
# (('Number of items', '2015', '1880.0'), 95673.0)
# (('Weight in kilograms', '2001', '48811.0'), 473815.0)
# (('Weight in kilograms', '2002', '8804910.0'), 1629835.0)
# (('Weight in kilograms', '2001', '3000.0'), 17580.0)
# (('Weight in kilograms', '1996', '2.0'), 8.0)
# (('Weight in kilograms', '2004', '52602.0'), 50323.0)
# (('Weight in kilograms', '2007', '75878.0'), 488966.0)
# (('Weight in kilograms', '2000', '75449.0'), 63093.0)
# (('Number of items', '2004', '6240.0'), 8967.0)
# (('Volume in litres', '1999', '471871.0'), 492001.0)
# (('Weight in kilograms', '2013', '151105.0'), 1028438.0)
# (('Weight in kilograms', '1991', '1791760.0'), 5152086.0)
# (('Weight in kilograms', '1996', '1647.0'), 5001.0)
# (('Weight in kilograms', '2004', '512930.0'), 1933697.0)
# (('Weight in kilograms', '1999', '5586.0'), 58657.0)
# (('Weight in kilograms', '2012', '919948.0'), 1037710.0)
# (('Weight in kilograms', '2007', '511.0'), 2976.0)
# (('Weight in kilograms', '2001', '423423.0'), 302868.0)
# (('Weight in kilograms', '1996', '3538.0'), 6498.0)
# (('Weight in kilograms', '2008', '535656.0'), 67430.0)
# (('Weight in kilograms', '1996', '5.0'), 736.0)
# (('Weight in kilograms', '2015', '500.0'), 1906.0)
# (('Weight in kilograms', '1994', '34582108.0'), 20219092.0)
# (('Number of items', '2016', '26867.0'), 455552.0)
# (('Weight in kilograms', '2012', '42007.0'), 229615.0)
# (('Weight in kilograms', '2003', '42347.0'), 77320.0)
# (('Weight in kilograms', '2015', '87891.0'), 1370085.0)
# (('Weight in kilograms', '1999', '14035695.0'), 8480269.0)
# (('Weight in kilograms', '2014', '5768928.0'), 25871190.0)
# (('Weight in kilograms', '2010', '5573137.0'), 23771390.0)
# (('Weight in kilograms', '2000', '8501960.0'), 7317487.0)
# (('Weight in kilograms', '1997', '1125.0'), 16199.0)
# (('Volume in litres', '1997', '67199.0'), 155251.0)
# (('Weight in kilograms', '2016', '67314.0'), 593069.0)
# (('Weight in kilograms', '2014', '102932.0'), 751427.0)
# (('Weight in kilograms', '1991', '1823814.0'), 1630576.0)
# (('Number of items', '2002', '10.0'), 624.0)
# (('Weight in kilograms', '2016', '3798002.0'), 6692750.0)
# (('Weight in kilograms', '2006', '133317.0'), 1014176.0)
# (('Weight in kilograms', '1999', '9438.0'), 89690.0)
# (('Volume in litres', '1991', '7160.0'), 9858.0)
# (('Weight in kilograms', '1995', '1897323.0'), 6755013.0)
# (('Weight in kilograms', '1999', '798787.0'), 229268.0)
# (('Weight in kilograms', '2012', '684923.0'), 2949294.0)
# (('Weight in kilograms', '2002', '9.0'), 96.0)
# (('Weight in kilograms', '2009', '33.0'), 1040.0)
# (('Weight in kilograms', '2001', '246678.0'), 50622.0)
# (('Weight in kilograms', '1989', '45601.0'), 2782.0)
# (('Weight in kilograms', '1990', '10126559.0'), 10757648.0)
# (('Weight in kilograms', '2013', '1339.0'), 24950.0)
# (('Weight in kilograms', '2012', '90955.0'), 1684894.0)
# (('Weight in kilograms', '1996', '3001670.0'), 4142414.0)
# (('Weight in kilograms', '2015', '11133589.0'), 13325202.0)
# (('Number of items', '2001', '3071215.0'), 8359660.0)
# (('Weight in kilograms', '2009', '88520.0'), 260786.0)
# (('Weight in kilograms', '2013', '518.0'), 9080.0)
# (('Weight in kilograms', '2004', '39814.0'), 482999.0)
# (('Weight in kilograms', '1989', '25299.0'), 25413.0)
# (('Weight in kilograms', '2004', '28369.0'), 68552.0)
# (('Weight in kilograms', '2001', '211604.0'), 504884.0)
# (('Weight in kilograms', '2005', '352.0'), 5572.0)
# (('Weight in kilograms', '2006', '1342203.0'), 1784027.0)
# (('Weight in kilograms', '2003', '1599525.0'), 4872959.0)
# (('Weight in kilograms', '2012', '1446143.0'), 21394318.0)
# (('Weight in kilograms', '2015', '4255730.0'), 1232751.0)
# (('Weight in kilograms', '2014', '45341786.0'), 100116060.0)
# (('Weight in kilograms', '2004', '510.0'), 4428.0)
# (('Weight in kilograms', '1994', '300122.0'), 1501019.0)
# (('Weight in kilograms', '2011', '3872889.0'), 11406490.0)
# (('Weight in kilograms', '2010', '125048.0'), 780866.0)
# (('Number of items', '2009', '20017.0'), 75008.0)
# (('Weight in kilograms', '2005', '39607849.0'), 31268007.0)
# (('Weight in kilograms', '1998', '2074250.0'), 569492.0)
# (('Weight in kilograms', '1998', '31203.0'), 22253.0)
# (('Weight in kilograms', '2009', '6325.0'), 80851.0)
# (('Weight in kilograms', '2012', '108962.0'), 406826.0)
# (('Weight in kilograms', '2002', '1909626.0'), 6145646.0)
# (('Weight in kilograms', '1996', '1023.0'), 6145.0)
# (('Weight in kilograms', '1993', '517904.0'), 707274.0)
# (('Number of items', '2000', '1653.0'), 87893282.0)
# (('Number of items', '2001', '525.0'), 23567.0)
# (('Weight in kilograms', '2010', '145.0'), 8022.0)
# (('Weight in kilograms', '2008', '14769.0'), 111067.0)
# (('Weight in kilograms', '1996', '52187.0'), 360006.0)
# (('Weight in kilograms', '1997', '1051292.0'), 5030243.0)
# (('Weight in kilograms', '1994', '28257728.0'), 3333568.0)
# (('Weight in kilograms', '1996', '58376640.0'), 1135480576.0)
# (('Weight in kilograms', '2013', '40225221.0'), 26125254.0)
# (('Weight in kilograms', '1994', '5371.0'), 34767.0)
# (('Weight in kilograms', '2009', '36365.0'), 64706.0)
# (('Weight in kilograms', '2014', '2000.0'), 4766.0)
# (('Weight in kilograms', '2011', '410076.0'), 5659087.0)
# (('Weight in kilograms', '2008', '5194.0'), 72311.0)
# (('Weight in kilograms', '1997', '934.0'), 8564.0)
# (('Number of items', '2015', '211815.0'), 209541454.0)
# (('Weight in kilograms', '2008', '35202705.0'), 244328484.0)
# (('Weight in kilograms', '1991', '10180.0'), 42239.0)
# (('Weight in kilograms', '2009', '4711.0'), 103459.0)
# (('Weight in kilograms', '2001', '8934.0'), 2550.0)
# (('Weight in kilograms', '2010', '17978494.0'), 3653815.0)
# (('Weight in kilograms', '2009', '2219096.0'), 8665915.0)
# (('Weight in kilograms', '1996', '1287537024.0'), 418010976.0)
# (('Weight in kilograms', '1995', '345.0'), 24610.0)
# (('Weight in kilograms', '2004', '3259.0'), 3467.0)
# (('Weight in kilograms', '1990', '5562.0'), 8144.0)
# (('Weight in kilograms', '2008', '850839.0'), 1785214.0)
# (('Number of items', '2008', '2939.0'), 267791.0)
# (('Weight in kilograms', '1993', '296718.0'), 129695.0)
# (('Weight in kilograms', '1993', '249.0'), 325.0)
# (('Weight in kilograms', '2012', '132075.0'), 350156.0)
# (('Weight in kilograms', '2004', '8639500.0'), 4646179.0)
# (('Weight in kilograms', '2011', '9926.0'), 231019.0)
# (('Weight in kilograms', '2010', '100219767.0'), 614236704.0)
# (('Weight in kilograms', '2014', '1100.0'), 15250.0)
# (('Weight in kilograms', '2008', '16963.0'), 1115978.0)
# (('Number of items', '2005', '1745549.0'), 6386718.0)
# (('Weight in kilograms', '1994', '163452.0'), 101355.0)
# (('Weight in kilograms', '2006', '3933299.0'), 8954618.0)
# (('Weight in kilograms', '1998', '230529.0'), 2698172.0)
# (('Weight in kilograms', '1994', '987375.0'), 2741211.0)
# (('Weight in kilograms', '1997', '175536.0'), 179004.0)
# (('Weight in kilograms', '1999', '35140.0'), 472829.0)
# (('Weight in kilograms', '1999', '455288.0'), 883328.0)
# (('Weight in kilograms', '2012', '342228.0'), 4986767.0)
# (('Volume in litres', '1998', '650155.0'), 1272647.0)
# (('Weight in kilograms', '2001', '1443.0'), 16449.0)
# (('Weight in kilograms', '1999', '1329455.0'), 467689.0)
# (('Weight in kilograms', '2016', '365403.0'), 436459.0)
# (('Weight in kilograms', '2013', '1105.0'), 15608.0)
# (('Weight in kilograms', '1991', '106499120.0'), 41584368.0)
# (('Weight in kilograms', '1996', '223752.0'), 3477940.0)
# (('Weight in kilograms', '2005', '9913.0'), 74908.0)
# (('Weight in kilograms', '1991', '48543.0'), 249520.0)
# (('Weight in kilograms', '1999', '945.0'), 10020.0)
# (('Number of items', '2003', '55511.0'), 508960.0)
# (('Number of items', '2006', '115255.0'), 1735228.0)
# (('Weight in kilograms', '2011', '61.0'), 8840.0)
# (('Weight in kilograms', '1995', '13937.0'), 111296.0)
# (('Weight in kilograms', '2004', '487728.0'), 2711839.0)
# (('Number of items', '2011', '111130.0'), 1095097.0)
# (('Weight in kilograms', '1994', '37746.0'), 15871.0)
# (('Weight in kilograms', '2014', '1170357.0'), 31532233.0)
# (('Weight in kilograms', '2006', '1051.0'), 9511.0)
# (('Weight in kilograms', '2015', '14903.0'), 392808.0)
# (('Weight in kilograms', '1997', '329832.0'), 3723583.0)
# (('Number of items', '2010', '30864.0'), 534101.0)
# (('Weight in kilograms', '1993', '5355704.0'), 20404728.0)
# (('Weight in kilograms', '2003', '20906.0'), 582398.0)
# (('Weight in kilograms', '2001', '1844426.0'), 4575322.0)
# (('Weight in kilograms', '2011', '618025.0'), 2020447.0)
# (('Weight in kilograms', '1996', '7343243.0'), 6830988.0)
# (('Weight in kilograms', '1991', '79097.0'), 50930.0)
# (('Number of items', '2001', '27350.0'), 22486.0)
# (('Weight in kilograms', '1997', '518067.0'), 9717271.0)
# (('Weight in kilograms', '1996', '585733.0'), 1484687.0)
# (('Weight in kilograms', '2006', '8363502.0'), 830606.0)
# (('Number of items', '2002', '5604.0'), 17032.0)
# (('Weight in kilograms', '2014', '175660670.0'), 89800890.0)
# (('Weight in kilograms', '2001', '157117911.0'), 36063360.0)
# (('Weight in kilograms', '1993', '460000.0'), 568682.0)
# (('Weight in kilograms', '1991', '58291.0'), 14380.0)
# (('Weight in kilograms', '1993', '558139.0'), 853514.0)
# (('Weight in kilograms', '1990', '2648.0'), 25571.0)
# (('Weight in kilograms', '2001', '7492.0'), 98496.0)
# (('Weight in kilograms', '2000', '13473.0'), 97401.0)
# (('Weight in kilograms', '1989', '25.0'), 431.0)
# (('Area in square metres', '2008', '26711.0'), 236874.0)
# (('Area in square metres', '2003', '768.0'), 5169.0)
# (('Weight in kilograms', '2006', '19360.0'), 42592.0)
# (('Weight in kilograms', '1999', '16431.0'), 349666.0)
# (('Weight in kilograms', '2002', '4423875.0'), 879668.0)
# (('Number of items', '2014', '56.0'), 645.0)
# (('Number of items', '2011', '69880.0'), 141792675.0)
# (('Weight in kilograms', '2000', '284.0'), 74525.0)
# (('Weight in kilograms', '1994', '26149.0'), 10466.0)
# (('Number of items', '2009', '33306.0'), 432696.0)
# (('Weight in kilograms', '2014', '68065830.0'), 121695714.0)
# (('Weight in kilograms', '1991', '9753.0'), 56661.0)
# (('Weight in kilograms', '1995', '1925.0'), 68172.0)
# (('Weight in kilograms', '2003', '473750.0'), 3126467.0)
# (('Weight in kilograms', '2008', '1405.0'), 25078.0)
# (('Weight in kilograms', '1993', '101.0'), 827.0)
# (('Weight in kilograms', '2011', '1882976.0'), 24044896.0)
# (('Weight in kilograms', '2002', '426822.0'), 1082256.0)
# (('Weight in kilograms', '2002', '20936.0'), 158058.0)
# (('Weight in kilograms', '1991', '2276184.0'), 1018159.0)
# (('Weight in kilograms', '2010', '723.0'), 177277.0)
# (('Weight in kilograms', '1997', '1044.0'), 12409.0)
# (('Weight in kilograms', '1998', '94103.0'), 533207.0)
# (('Weight in kilograms', '2013', '7899.0'), 689857.0)
# (('Weight in kilograms', '1993', '5875.0'), 17615.0)
# (('Weight in kilograms', '2014', '11067604.0'), 8284187.0)
# (('Weight in kilograms', '2005', '2132678.0'), 3527706.0)
# (('Weight in kilograms', '1994', '23767.0'), 95142.0)
# (('Weight in kilograms', '2012', '70.0'), 59.0)
# (('Weight in kilograms', '2004', '860.0'), 15894.0)
# (('Weight in kilograms', '1999', '1354.0'), 20966.0)
# (('Weight in kilograms', '1990', '124343.0'), 18189.0)
# (('Weight in kilograms', '1994', '16508333.0'), 42167448.0)
# (('Number of pairs', '2001', '4640322.0'), 33256549.0)
# (('Weight in kilograms', '2006', '16966.0'), 17015.0)
# (('Volume in litres', '2001', '1218203.0'), 507522.0)
# (('Weight in kilograms', '2005', '4551150.0'), 23020919.0)
# (('Weight in kilograms', '2005', '1500.0'), 4428.0)
# (('Weight in kilograms', '2003', '134596.0'), 115362.0)
# (('Weight in kilograms', '2006', '10092823.0'), 17236975.0)
# (('Weight in kilograms', '2015', '527331.0'), 2348038.0)
# (('Weight in kilograms', '1989', '1971198.0'), 2542889.0)
# (('Weight in kilograms', '1999', '931.0'), 13831.0)
# (('Weight in kilograms', '2002', '200873.0'), 335310.0)
# (('Weight in kilograms', '1997', '65377.0'), 1167456.0)
# (('Volume in cubic meters', '2011', '472907.0'), 131740.0)
# (('Weight in kilograms', '2007', '507.0'), 6286.0)
# (('Weight in kilograms', '2014', '8297.0'), 96158.0)
# (('Weight in kilograms', '1991', '29.0'), 607.0)
# (('Weight in kilograms', '2009', '17675.0'), 24273.0)
# (('Weight in kilograms', '1995', '59884512.0'), 21315788.0)
# (('Weight in kilograms', '2007', '36904.0'), 120370.0)
# (('Weight in kilograms', '2003', '283366.0'), 5433021.0)
# (('Weight in kilograms', '2013', '54720.0'), 488011.0)
# (('Weight in kilograms', '2004', '6765.0'), 14117.0)
# (('Number of items', '2000', '359590.0'), 1030526.0)
# (('Weight in kilograms', '2013', '314.0'), 1515.0)
# (('Number of pairs', '2011', '169460.0'), 5525613.0)
# (('Weight in kilograms', '1993', '117575.0'), 457713.0)
# (('Weight in kilograms', '2000', '334716.0'), 1040812.0)
# (('Weight in kilograms', '2006', '1.0'), 10.0)
# (('Number of items', '2015', '20596.0'), 176175.0)
# (('Weight in kilograms', '1994', '144449.0'), 873237.0)
# (('Weight in kilograms', '2006', '84201.0'), 90196.0)
# (('Weight in kilograms', '1998', '196617.0'), 1194192.0)
# (('Weight in kilograms', '2008', '7.0'), 28.0)
# (('Weight in kilograms', '2014', '28414675.0'), 22386254.0)
# (('Weight in kilograms', '2004', '23932.0'), 135388.0)
# (('Weight in kilograms', '1989', '482807.0'), 852404.0)
# (('Weight in kilograms', '2003', '1844.0'), 8108.0)
# (('Weight in kilograms', '1999', '10945498.0'), 8349306.0)
# (('Weight in kilograms', '2003', '2906520.0'), 13710922.0)
# (('Weight in kilograms', '1998', '20234.0'), 555391.0)
# (('Weight in kilograms', '1994', '7321.0'), 22420.0)
# (('Weight in kilograms', '1993', '15147.0'), 171938.0)
# (('Weight in kilograms', '2000', '2766890.0'), 6786627.0)
# (('Weight in kilograms', '1994', '1480556.0'), 130624.0)
# (('Weight in kilograms', '1999', '209502.0'), 73205.0)
# (('Weight in kilograms', '1999', '5172.0'), 109402.0)
# (('Number of items', '2002', '10070.0'), 1173850.0)
# (('Weight in kilograms', '1995', '218.0'), 2625.0)
# (('Weight in kilograms', '2000', '1763977.0'), 492893.0)
# (('Weight in kilograms', '2006', '531051.0'), 1651367.0)
# (('Weight in kilograms', '2015', '14826662383.0'), 5821073682.0)
# (('Weight in kilograms', '2013', '500720254.0'), 254046101.0)
# (('Volume in litres', '1995', '4224594.0'), 2003445.0)
# (('Weight in kilograms', '2004', '28545669.0'), 5667684.0)
# (('Weight in kilograms', '1997', '37248008.0'), 52322328.0)
# (('Number of items', '2002', '24772.0'), 38505.0)
# (('Weight in kilograms', '2012', '20312730.0'), 31487584.0)
# (('Weight in kilograms', '1993', '306469.0'), 3535815.0)
# (('Weight in kilograms', '2001', '181496.0'), 1050741.0)
# (('Number of pairs', '2016', '85417.0'), 1532650.0)
# (('Weight in kilograms', '1992', '906264.0'), 4646338.0)
# (('Weight in kilograms', '2015', '1159145.0'), 4661804.0)
# (('Weight in kilograms', '2011', '510058.0'), 32549712.0)
# (('Weight in kilograms', '1995', '54.0'), 177.0)
# (('Weight in kilograms', '1991', '124000.0'), 114700.0)
# (('Weight in kilograms', '2009', '57288142.0'), 23848215.0)
# (('Weight in kilograms', '1990', '16811.0'), 112660.0)
# (('Number of items', '2015', '203983.0'), 1120386.0)
# (('Weight in kilograms', '2013', '5561658.0'), 5622223.0)
# (('Weight in kilograms', '2013', '518000.0'), 1106640.0)
# (('Weight in kilograms', '2008', '72279.0'), 655255.0)
# (('Weight in kilograms', '2008', '10930738.0'), 56444558.0)
# (('Weight in kilograms', '2002', '11.0'), 133.0)
# (('Weight in kilograms', '2007', '8146294.0'), 15581675.0)
# (('Weight in kilograms', '1997', '692421.0'), 119007.0)
# (('Weight in kilograms', '2005', '18137.0'), 204219.0)
# (('Weight in kilograms', '1995', '4567.0'), 96377.0)
# (('Weight in kilograms', '1996', '1881787.0'), 3101145.0)
# (('Weight in kilograms', '1994', '50062.0'), 48911.0)
# (('Weight in kilograms', '1991', '276873.0'), 1511358.0)
# (('Weight in kilograms', '2016', '282793.0'), 348142.0)
# (('Weight in kilograms', '2008', '4026.0'), 242092.0)
# (('Weight in kilograms', '2016', '2516721.0'), 4140299.0)
# (('Weight in kilograms', '1997', '46495944.0'), 180914128.0)
# (('Weight in kilograms', '2003', '23993047.0'), 42938161.0)
# (('Weight in kilograms', '1995', '3502.0'), 79716.0)
# (('Weight in kilograms', '1992', '8022474.0'), 36732152.0)
# (('Volume in cubic meters', '2000', '591075.0'), 184287004.0)
# (('Weight in kilograms', '1994', '155129.0'), 3132027.0)
# (('Weight in kilograms', '1993', '8730.0'), 88605.0)
# (('Weight in kilograms', '1993', '4871.0'), 55634.0)
# (('Weight in kilograms', '2014', '2302.0'), 9170.0)
# (('Weight in kilograms', '2003', '14236.0'), 45533.0)
# (('Weight in kilograms', '1990', '952687.0'), 864052.0)
# (('Weight in kilograms', '2008', '11960369.0'), 10403065.0)
# (('Weight in kilograms', '2008', '130031.0'), 1056664.0)
# (('Number of items', '2014', '1572.0'), 335472.0)
# (('Number of items', '2002', '268.0'), 6926.0)
# (('Weight in kilograms', '1992', '1575195.0'), 3345139.0)
# (('Weight in kilograms', '2000', '2874623.0'), 610695.0)
# (('Weight in kilograms', '2006', '1489632.0'), 13063675.0)
# (('Weight in kilograms', '1989', '216777.0'), 302194.0)
# (('Weight in kilograms', '2008', '2073.0'), 1095459.0)
# (('Volume in litres', '2006', '732538.0'), 695533.0)
# (('Number of items', '2000', '6.0'), 10716024.0)
# (('Weight in kilograms', '2004', '30127581.0'), 32651301.0)
# (('Weight in kilograms', '2014', '11482654.0'), 22708887.0)
# (('Weight in kilograms', '1999', '1590400.0'), 6007247.0)
# (('Weight in kilograms', '2001', '202.0'), 3812.0)
# (('Weight in kilograms', '2007', '46070.0'), 738826.0)
# (('Weight in kilograms', '2001', '156192.0'), 1978881.0)
# (('Weight in kilograms', '2016', '5103.0'), 3081.0)
# (('Number of items', '2004', '216.0'), 34944.0)
# (('Weight in kilograms', '2013', '11367133.0'), 32232673.0)
# (('Volume in litres', '2011', '17848.0'), 361945.0)
# (('Weight in kilograms', '2016', '2809237.0'), 6924304.0)
# (('Weight in kilograms', '1998', '2261.0'), 22306.0)
# (('Weight in kilograms', '2013', '85312.0'), 223839.0)
# (('Weight in kilograms', '2012', '162.0'), 576.0)
# (('Number of items', '2003', '118.0'), 9223.0)
# (('Weight in kilograms', '2011', '102516.0'), 539238.0)
# (('Number of items', '2007', '75708.0'), 1042120.0)
# (('Weight in kilograms', '2006', '22858775.0'), 9299644.0)
# (('Weight in kilograms', '1998', '1190.0'), 22683.0)
# (('Weight in kilograms', '2009', '92.0'), 18929.0)
# (('Weight in kilograms', '2014', '1010904.0'), 7421000.0)
# (('Weight in kilograms', '2002', '57708.0'), 1759301.0)
# (('Weight in kilograms', '2009', '97845.0'), 1606830.0)
# (('Weight in kilograms', '1997', '1448613.0'), 2667882.0)
# (('Number of items', '2008', '10167.0'), 717647.0)
# (('Weight in kilograms', '1998', '3315.0'), 61206.0)
# (('Weight in kilograms', '2010', '30474847.0'), 21033268.0)
# (('Weight in kilograms', '1995', '296295.0'), 128583.0)
# (('Weight in kilograms', '1993', '427560.0'), 829163.0)
# (('Weight in kilograms', '1991', '100.0'), 3544.0)
# (('Weight in kilograms', '1991', '74789.0'), 34462.0)
# (('Weight in kilograms', '1996', '39170.0'), 898015.0)
# (('Weight in kilograms', '1995', '179691.0'), 951434.0)
# (('Weight in kilograms', '1990', '3237.0'), 80505.0)
# (('Weight in kilograms', '1996', '1.0'), 15.0)
# (('Weight in kilograms', '1992', '970711.0'), 2231814.0)
# (('Number of items', '2014', '873.0'), 101509.0)
# (('Weight in kilograms', '2000', '476336.0'), 17672.0)
# (('Weight in kilograms', '1998', '3838.0'), 26837.0)
# (('Weight in kilograms', '1998', '9451.0'), 74762.0)
# (('Volume in litres', '1999', '2634.0'), 1355.0)
# (('Weight in kilograms', '2016', '520870.0'), 131025.0)
# (('Weight in kilograms', '2011', '1335.0'), 11782.0)
# (('Weight in kilograms', '2010', '954.0'), 7043.0)
# (('Weight in kilograms', '1996', '263392.0'), 3466895.0)
# (('Weight in kilograms', '2016', '5985487.0'), 32402519.0)
# (('Weight in kilograms', '1992', '85521.0'), 24614.0)
# (('Weight in kilograms', '2016', '1254552.0'), 9245093.0)
# (('Weight in kilograms', '1995', '4437.0'), 17830.0)
# (('Weight in kilograms', '2008', '1142343.0'), 27587581.0)
# (('Weight in kilograms', '1989', '222366.0'), 901787.0)
# (('Weight in kilograms', '1989', '8.0'), 731.0)
# (('Weight in kilograms', '2004', '4500.0'), 11520.0)
# (('Weight in kilograms', '2004', '121800.0'), 203364.0)
# (('Weight in kilograms', '2009', '379.0'), 1806.0)
# (('Weight in kilograms', '2002', '390008.0'), 3299033.0)
# (('Weight in kilograms', '1995', '18267060.0'), 13513016.0)
# (('Weight in kilograms', '2012', '4183.0'), 19340.0)
# (('Weight in kilograms', '2007', '135289.0'), 996145.0)
# (('Weight in kilograms', '2006', '1006580.0'), 1241664.0)
# (('Weight in kilograms', '1994', '2196.0'), 68733.0)
# (('Weight in kilograms', '1996', '8007.0'), 17647.0)
# (('Weight in kilograms', '2013', '20.0'), 1611.0)
# (('Weight in kilograms', '2010', '8998138.0'), 13446855.0)
# (('Weight in kilograms', '1998', '176.0'), 4391.0)
# (('Weight in kilograms', '2000', '5326.0'), 37032.0)
# (('Weight in kilograms', '2012', '36.0'), 576.0)
# (('Weight in kilograms', '1994', '463.0'), 1911.0)
# (('Weight in kilograms', '2012', '1766.0'), 24899.0)
# (('Weight in kilograms', '2010', '242672.0'), 1051922.0)
# (('Weight in kilograms', '2004', '54379751.0'), 218874494.0)
# (('Weight in kilograms', '1991', '44000.0'), 16748.0)
# (('Number of items', '2009', '318.0'), 16608.0)
# (('Number of pairs', '2005', '7161394.0'), 48581295.0)
# (('Weight in kilograms', '2003', '5250084.0'), 2626595.0)
# (('Weight in kilograms', '1993', '23547.0'), 282454.0)
# (('Weight in kilograms', '1997', '92967.0'), 286873.0)
# (('Weight in kilograms', '1992', '324779.0'), 11118102.0)
# (('Number of items', '2011', '143128.0'), 1314038223.0)
# (('Weight in kilograms', '2014', '3509311.0'), 12175176.0)
# (('Weight in kilograms', '1992', '311711.0'), 561950.0)
# (('Weight in kilograms', '1998', '149394560.0'), 40187892.0)
# (('Weight in kilograms', '2013', '2067872842.0'), 4198991799.0)
# (('Weight in kilograms', '2005', '22403.0'), 220338.0)
# (('Weight in kilograms', '1992', '268925.0'), 342966.0)
# (('Weight in kilograms', '1990', '27513.0'), 333919.0)
# (('Weight in kilograms', '1995', '14062.0'), 22500.0)
# (('Weight in kilograms', '2001', '639608.0'), 6934064.0)
# (('Weight in kilograms', '1992', '28358.0'), 139823.0)
# (('Weight in kilograms', '1990', '2441742.0'), 3170529.0)
# (('Weight in kilograms', '1990', '237736.0'), 782246.0)
# (('Weight in kilograms', '1991', '23703464.0'), 68496144.0)
# (('Weight in kilograms', '1998', '117.0'), 8844.0)
# (('Weight in kilograms', '1996', '330.0'), 7278.0)
# (('Weight in kilograms', '1995', '573466.0'), 370777.0)
# (('Weight in kilograms', '1992', '181000.0'), 272334.0)
# (('Weight in kilograms', '2011', '481489.0'), 193943.0)
# (('Weight in kilograms', '2010', '563521.0'), 2675776.0)
# (('Weight in kilograms', '1992', '7146.0'), 44455.0)
# (('Weight in kilograms', '2009', '4461629.0'), 2738172.0)
# (('Weight in kilograms', '1994', '34747.0'), 270065.0)
# (('Weight in kilograms', '2001', '525751.0'), 2724794.0)
# (('Weight in kilograms', '2008', '30442476.0'), 94701948.0)
# (('Weight in kilograms', '1997', '13858133.0'), 8789354.0)
# (('Weight in kilograms', '1990', '500.0'), 500.0)
# (('Weight in kilograms', '2001', '15878685.0'), 17770466.0)
# (('Number of items', '2015', '387.0'), 6319.0)
# (('Weight in kilograms', '2009', '190098.0'), 432037.0)
# (('Weight in kilograms', '2005', '32382.0'), 256600.0)
# (('Weight in kilograms', '2014', '3719892.0'), 1257902.0)
# (('Weight in kilograms', '2003', '642002.0'), 799420.0)
# (('Weight in kilograms', '2002', '196002.0'), 1343452.0)
# (('Weight in kilograms', '1989', '2884073.0'), 5512438.0)
# (('Weight in kilograms', '2010', '319210.0'), 1118132.0)
# (('Weight in kilograms', '1993', '8718506.0'), 13999817.0)
# (('Weight in kilograms', '1992', '541291.0'), 7277047.0)
# (('Number of items', '2011', '498737.0'), 20131223.0)
# (('Weight in kilograms', '2008', '61645.0'), 1179522.0)
# (('Weight in kilograms', '2006', '539744.0'), 690929.0)
# (('Weight in kilograms', '1999', '262619.0'), 67902.0)
# (('Weight in kilograms', '2015', '24931.0'), 496465.0)
# (('Weight in kilograms', '2010', '1143501.0'), 6542119.0)
# (('Weight in kilograms', '2004', '80855.0'), 216752.0)
# (('Weight in kilograms', '2010', '27989.0'), 113526.0)
# (('Weight in kilograms', '2005', '14020.0'), 45839.0)
# (('Weight in kilograms', '2012', '803144.0'), 9193431.0)
# (('Weight in kilograms', '2003', '464831749.0'), 726034778.0)
# (('Volume in litres', '2016', '2270.0'), 5143.0)
# (('Number of items', '2000', '1063841.0'), 16069583.0)
# (('Weight in kilograms', '1995', '7892.0'), 37999.0)
# (('Number of items', '2003', '529.0'), 1099359.0)
# (('Weight in kilograms', '2012', '12090715.0'), 12074518.0)
# (('Weight in kilograms', '2011', '34.0'), 16.0)
# (('Weight in kilograms', '1993', '62022.0'), 275531.0)
# (('Weight in kilograms', '2007', '16312964.0'), 25550482.0)
# (('Weight in kilograms', '1992', '1127658.0'), 3150756.0)
# (('Weight in kilograms', '2010', '66947570.0'), 1556668696.0)
# (('Weight in kilograms', '1991', '32475224.0'), 19649882.0)
# (('Weight in kilograms', '2009', '143871502.0'), 39394960.0)
# (('Area in square metres', '2005', '126921.0'), 803170.0)
# (('Weight in kilograms', '2001', '37214582.0'), 3057192.0)
# (('Weight in kilograms', '1999', '3010.0'), 8234.0)
# (('Weight in kilograms', '1994', '1108599.0'), 715053.0)
# (('Area in square metres', '2003', '76169.0'), 398705.0)
# (('Weight in kilograms', '1994', '334185.0'), 619544.0)
# (('Weight in kilograms', '2008', '36000.0'), 174250.0)
# (('Weight in kilograms', '1991', '84749856.0'), 86226248.0)
# (('Number of items', '2005', '5747.0'), 288694.0)
# (('Weight in kilograms', '2016', '13866659.0'), 4573793.0)
# (('Number of items', '2011', '57494.0'), 716614.0)
# (('Weight in kilograms', '2010', '62.0'), 166.0)
# (('Weight in kilograms', '2007', '19505.0'), 74684.0)
# (('Weight in kilograms', '1992', '730750.0'), 628971.0)
# (('Weight in kilograms', '2016', '4603.0'), 14001.0)
# (('Weight in kilograms', '1994', '53000.0'), 73273.0)
# (('Weight in kilograms', '2011', '9991177.0'), 4468278.0)
# (('Number of items', '2001', '702679.0'), 2634713.0)
# (('Weight in kilograms', '2007', '330686.0'), 1705882.0)
# (('Number of items', '2006', '202.0'), 13648.0)
# (('Weight in kilograms', '2001', '499192.0'), 415099.0)
# (('Weight in kilograms', '1990', '21.0'), 273.0)
# (('Weight in kilograms', '1998', '4768.0'), 26113.0)
# (('Weight in kilograms', '2001', '5332.0'), 35486.0)
# (('Weight in kilograms', '1989', '312.0'), 3133.0)
# (('Weight in kilograms', '2014', '7011.0'), 36652.0)
# (('Weight in kilograms', '2016', '985.0'), 2912.0)
# (('Weight in kilograms', '2006', '136506.0'), 1148622.0)
# (('Weight in kilograms', '2010', '311838.0'), 512625.0)
# (('Weight in kilograms', '2008', '302120.0'), 3837933.0)
# (('Weight in kilograms', '1992', '12600.0'), 189668.0)
# (('Weight in kilograms', '2007', '173800.0'), 515908.0)
# (('Weight in kilograms', '2002', '452951.0'), 1260813.0)
# (('Number of items', '2014', '950.0'), 435616.0)
# (('Weight in kilograms', '2015', '3.0'), 9110.0)
# (('Weight in kilograms', '2014', '30852.0'), 267138.0)
# (('Weight in kilograms', '1991', '1659.0'), 391.0)
# (('Weight in kilograms', '2004', '174252.0'), 569294.0)
# (('Weight in kilograms', '2005', '366471.0'), 3762352.0)
# (('Weight in kilograms', '1991', '4500.0'), 5240.0)
# (('Weight in kilograms', '1997', '33743.0'), 572946.0)
# (('Weight in kilograms', '2007', '102.0'), 3010.0)
# (('Weight in kilograms', '2003', '70192294.0'), 230811808.0)
# (('Weight in kilograms', '1995', '25000.0'), 18149.0)
# (('Weight in kilograms', '1996', '53021.0'), 503496.0)
# (('Weight in kilograms', '1991', '9400.0'), 174400.0)
# (('Weight in kilograms', '2007', '1500516.0'), 5170339.0)
# (('Weight in kilograms', '2012', '2611506.0'), 3341940.0)
# (('Weight in kilograms', '2014', '76768.0'), 731924.0)
# (('Weight in kilograms', '2008', '315.0'), 2940.0)
# (('Weight in kilograms', '2000', '263393.0'), 437476.0)
# (('Weight in kilograms', '2015', '17179838.0'), 21792045.0)
# (('Weight in kilograms', '1990', '214699.0'), 124071.0)
# (('Weight in kilograms', '2003', '128.0'), 4786.0)
# (('Weight in kilograms', '1996', '3752361.0'), 1458129.0)
# (('Weight in kilograms', '2009', '385.0'), 7938.0)
# (('Number of items', '2014', '3.0'), 6245.0)
# (('Weight in kilograms', '2010', '49779.0'), 222532.0)
# (('Weight in kilograms', '2004', '18108.0'), 26515.0)
# (('Weight in kilograms', '2004', '98818339.0'), 54165450.0)
# (('Weight in kilograms', '2008', '80802205.0'), 55604254.0)
# (('Weight in kilograms', '1999', '3013173.0'), 3222573.0)
# (('Weight in kilograms', '1996', '4807406.0'), 10456170.0)
# (('Number of items', '2005', '2338.0'), 426277.0)
# (('Weight in kilograms', '1990', '4251202.0'), 2997276.0)
# (('Weight in kilograms', '2005', '7082480.0'), 11648357.0)
# (('Weight in kilograms', '2009', '4461.0'), 124107.0)
# (('Weight in kilograms', '2010', '10117.0'), 127121.0)
# (('Weight in kilograms', '2008', '916438.0'), 5042842.0)
# (('Weight in kilograms', '2016', '29063.0'), 1391627.0)
# (('Weight in kilograms', '2003', '459965.0'), 2472975.0)
# (('Weight in kilograms', '1998', '1750.0'), 6537.0)
# (('Weight in kilograms', '2010', '6941919.0'), 18825979.0)
# (('Weight in kilograms', '1996', '269187.0'), 55000000.0)
# (('Weight in kilograms', '1996', '4395.0'), 55789.0)
# (('Volume in litres', '2007', '619.0'), 1124.0)
# (('Weight in kilograms', '2013', '498346.0'), 1627777.0)
# (('Weight in kilograms', '2002', '18167.0'), 85172.0)
# (('Weight in kilograms', '1992', '11998.0'), 65126.0)
# (('Weight in kilograms', '2004', '355653.0'), 3342341.0)
# (('Weight in kilograms', '2006', '1964669.0'), 1517040.0)
# (('Weight in kilograms', '2015', '1196010.0'), 1409596.0)
# (('Number of items', '2011', '252.0'), 14455.0)
# (('Weight in kilograms', '1994', '2822863.0'), 3809559.0)
# (('Weight in kilograms', '1996', '1730204.0'), 6859475.0)
# (('Weight in kilograms', '2009', '214164.0'), 2685884.0)
# (('Weight in kilograms', '1994', '15243659.0'), 10056631.0)
# (('Weight in kilograms', '1991', '64.0'), 2137.0)
# (('Weight in kilograms', '2016', '6226.0'), 29581.0)
# (('Number of items', '2001', '66.0'), 2894.0)
# (('Weight in kilograms', '2006', '693996.0'), 8484546.0)
# (('Weight in kilograms', '1999', '292863.0'), 447148.0)
# (('Weight in kilograms', '2012', '1731255.0'), 15659323.0)
# (('Weight in kilograms', '2014', '640344.0'), 1274353.0)
# (('Weight in kilograms', '2008', '54300.0'), 161841.0)
# (('Weight in kilograms', '2004', '1005.0'), 4230.0)
# (('Weight in kilograms', '2002', '31.0'), 625.0)
# (('Weight in kilograms', '2002', '25194.0'), 116899.0)
# (('Weight in kilograms', '2004', '235474673.0'), 421079638.0)
# (('Weight in kilograms', '2009', '187.0'), 1901.0)
# (('Weight in kilograms', '2006', '7948828.0'), 2315921.0)
# (('Weight in carats', '2008', '134552.0'), 9572587.0)
# (('Weight in kilograms', '2008', '3920723.0'), 6119908.0)
# (('Weight in kilograms', '2013', '9723.0'), 47414.0)
# (('Weight in kilograms', '1990', '1025705.0'), 2157546.0)
# (('Weight in kilograms', '2008', '171.0'), 107826.0)
# (('Weight in kilograms', '2006', '14282513.0'), 44402982.0)
# (('Weight in kilograms', '1995', '311851.0'), 2274871.0)
# (('Weight in kilograms', '1998', '20944.0'), 53590.0)
# (('Weight in kilograms', '1996', '20708.0'), 53616.0)
# (('Weight in kilograms', '2007', '483585.0'), 2366543.0)
# (('Weight in kilograms', '2001', '226489.0'), 141882.0)
# (('Weight in kilograms', '2002', '72806.0'), 350640.0)
# (('Weight in kilograms', '1990', '158.0'), 789.0)
# (('Weight in kilograms', '1995', '62779.0'), 342172.0)
# (('Weight in kilograms', '2014', '4466.0'), 12275.0)
# (('Weight in kilograms', '1998', '12500.0'), 1564.0)
# (('Weight in kilograms', '2006', '147628.0'), 589595.0)
# (('Number of items', '2006', '16616.0'), 432771852.0)
# (('Weight in kilograms', '1996', '94112.0'), 77115.0)
# (('Weight in kilograms', '2013', '163630.0'), 130024.0)
# (('Weight in kilograms', '2000', '16738918.0'), 12036989.0)
# (('Weight in kilograms', '2014', '323959.0'), 4377744.0)
# (('Weight in kilograms', '2010', '930185.0'), 1108618.0)
# (('Number of items', '2004', '31138867.0'), 60667867.0)
# (('Weight in kilograms', '1999', '125741.0'), 2676602.0)
# (('Weight in kilograms', '2003', '95.0'), 205.0)
# (('Weight in kilograms', '2012', '301.0'), 3542.0)
# (('Weight in kilograms', '1998', '15437.0'), 28328.0)
# (('Weight in kilograms', '1995', '41.0'), 62.0)
# (('Weight in kilograms', '1994', '7624.0'), 82387.0)
# (('Weight in kilograms', '2015', '1086515.0'), 15312121.0)
# (('Weight in kilograms', '2001', '33213.0'), 121139.0)
# (('Weight in kilograms', '2011', '154347.0'), 1235187.0)
# (('Weight in kilograms', '1992', '6160098.0'), 3627310.0)
# (('Weight in kilograms', '2005', '596484.0'), 250772.0)
# (('Weight in kilograms', '1992', '232.0'), 7756.0)
# (('Weight in kilograms', '2011', '7723.0'), 59351.0)
# (('Weight in kilograms', '1994', '15374368.0'), 10122539.0)
# (('Weight in kilograms', '2016', '787980.0'), 561638.0)
# (('Weight in kilograms', '2006', '11801.0'), 40192.0)
# (('Number of items', '2008', '544728.0'), 1605172.0)
# (('Area in square metres', '2009', '714.0'), 23045.0)
# (('Number of items', '2012', '368348.0'), 520033.0)
# (('Weight in kilograms', '2016', '20295.0'), 167409.0)
# (('Weight in kilograms', '2001', '571009.0'), 7231321.0)
# (('Weight in kilograms', '1999', '7690140.0'), 2856625.0)
# (('Weight in kilograms', '2002', '555.0'), 4918.0)
# (('Weight in kilograms', '1999', '486697.0'), 3073404.0)
# (('Weight in kilograms', '2016', '9852719.0'), 4612996.0)
# (('Weight in kilograms', '1994', '83178448.0'), 30659146.0)
# (('Weight in kilograms', '1996', '8125.0'), 16470.0)
# (('Weight in kilograms', '2016', '3014686.0'), 12828307.0)
# (('Weight in kilograms', '2005', '118879.0'), 982141.0)
# (('Weight in kilograms', '2006', '167.0'), 12764.0)
# (('Weight in kilograms', '2014', '46357.0'), 178943.0)
# (('Weight in kilograms', '2010', '5622870.0'), 14399331.0)
# (('Weight in kilograms', '2016', '141000.0'), 70323.0)
# (('Weight in kilograms', '1996', '401429.0'), 494093.0)
# (('Weight in kilograms', '2003', '18081.0'), 15970.0)
# (('Weight in kilograms', '2012', '3694.0'), 380038.0)
# (('Weight in kilograms', '2005', '3821793.0'), 12009157.0)
# (('Weight in kilograms', '1994', '38048.0'), 2946338.0)
# (('Weight in kilograms', '2010', '3941.0'), 81099.0)
# (('Weight in kilograms', '1994', '581242.0'), 3053045.0)
# (('Weight in kilograms', '2000', '136.0'), 200.0)
# (('Number of items', '2006', '144899.0'), 495928.0)
# (('Weight in kilograms', '1992', '5937.0'), 1999.0)
# (('Weight in kilograms', '2014', '6318948.0'), 23305474.0)
# (('Weight in kilograms', '2012', '40966.0'), 23108.0)
# (('Weight in kilograms', '2000', '3947.0'), 71787.0)
# (('Number of items', '2001', '245134.0'), 23011379.0)
# (('Weight in kilograms', '1990', '201658.0'), 532346.0)
# (('Weight in kilograms', '2004', '486709695.0'), 6113141.0)
# (('Weight in kilograms', '1994', '1628.0'), 12659.0)
# (('Weight in kilograms', '2001', '4637461.0'), 2250745.0)
# (('Weight in kilograms', '2002', '919040538.0'), 58566448.0)
# (('Weight in kilograms', '1990', '320.0'), 2870.0)
# (('Weight in kilograms', '1994', '1253.0'), 18052.0)
# (('Weight in kilograms', '1993', '162844.0'), 946574.0)
# (('Weight in kilograms', '2006', '585342.0'), 3140817.0)
# (('Weight in kilograms', '1994', '624698.0'), 1784373.0)
# (('Weight in kilograms', '1995', '2163.0'), 31920.0)
# (('Weight in kilograms', '2013', '4110662.0'), 1486935.0)
# (('Weight in kilograms', '2008', '21243931.0'), 63957614.0)
# (('Weight in kilograms', '2013', '205.0'), 28107.0)
# (('Weight in kilograms', '1994', '70.0'), 87.0)
# (('Weight in kilograms', '1997', '145941.0'), 2342312.0)
# (('Weight in kilograms', '2007', '15950.0'), 97377.0)
# (('Weight in kilograms', '2006', '380860.0'), 1689988.0)
# (('Weight in kilograms', '2006', '91963.0'), 629834.0)
# (('Weight in kilograms', '1998', '14008284.0'), 8938062.0)
# (('Weight in kilograms', '1998', '20843760.0'), 3062247.0)
# (('Weight in kilograms', '2009', '1353224.0'), 17529102.0)
# (('Weight in kilograms', '1994', '4000.0'), 14781.0)
# (('Weight in kilograms', '2005', '39049.0'), 11987.0)
# (('Weight in kilograms', '1991', '935641.0'), 3545255.0)
# (('Weight in kilograms', '2007', '5100531.0'), 49509898.0)
# (('Weight in kilograms', '2011', '12862585.0'), 5487014.0)
# (('Weight in kilograms', '1999', '392977.0'), 690900.0)
# (('Weight in kilograms', '2007', '12.0'), 293.0)
# (('Weight in kilograms', '2010', '30594.0'), 834132.0)
# (('Weight in kilograms', '2016', '160391.0'), 185561.0)
# (('Weight in kilograms', '1992', '10486518.0'), 1514544.0)
# (('Weight in kilograms', '2001', '1087.0'), 2320.0)
# (('Weight in kilograms', '2014', '684.0'), 84347.0)
# (('Weight in kilograms', '2014', '6339.0'), 15185171.0)
# (('Weight in kilograms', '1989', '132.0'), 8474.0)
# (('Weight in kilograms', '2001', '39019421.0'), 140085101.0)
# (('Weight in kilograms', '1990', '1230.0'), 14379.0)
# (('Weight in kilograms', '2005', '1039.0'), 6636.0)
# (('Weight in kilograms', '2012', '2081268.0'), 33218312.0)
# (('Weight in kilograms', '1995', '5999.0'), 8945.0)
# (('Weight in kilograms', '1997', '1109187.0'), 518136.0)
# (('Weight in kilograms', '1996', '5571996.0'), 15067685.0)
# (('Weight in kilograms', '2012', '60208.0'), 534948.0)
# (('Volume in cubic meters', '2015', '25823.0'), 9228760.0)
# (('Weight in kilograms', '2006', '13001.0'), 96777.0)
# (('Weight in kilograms', '1992', '70132.0'), 178695.0)
# (('Weight in kilograms', '2010', '1855057.0'), 4824321.0)
# (('Weight in kilograms', '2006', '21047.0'), 1710138.0)
# (('Weight in kilograms', '1991', '85664.0'), 803677.0)
# (('Weight in kilograms', '2007', '121644.0'), 164883.0)
# (('Weight in kilograms', '1989', '41325.0'), 289431.0)
# (('Weight in kilograms', '2009', '86940.0'), 155777.0)
# (('Number of items', '2002', '803.0'), 4104.0)
# (('Weight in kilograms', '1996', '26447.0'), 26020.0)
# (('Weight in kilograms', '1994', '30862.0'), 190984.0)
# (('Weight in kilograms', '2011', '47974.0'), 444578.0)
# (('Weight in kilograms', '2013', '1652.0'), 29412.0)
# (('Area in square metres', '2001', '737.0'), 14462.0)
# (('Weight in kilograms', '2004', '631.0'), 1607.0)
# (('Weight in kilograms', '1998', '443.0'), 2241.0)
# (('Weight in kilograms', '1993', '661615.0'), 5042212.0)
# (('Number of pairs', '2012', '140350.0'), 2121700.0)
# (('Weight in kilograms', '2005', '86397.0'), 83638.0)
# (('Number of items', '2010', '488523.0'), 5952878.0)
# (('Weight in kilograms', '1997', '76415.0'), 12920042.0)
# (('Weight in kilograms', '2000', '590.0'), 6848.0)
# (('Weight in kilograms', '1989', '430431.0'), 1399896.0)
# (('Weight in kilograms', '2007', '8897664.0'), 19139709.0)
# (('Weight in kilograms', '1998', '520468.0'), 2165986.0)
# (('Number of items', '2005', '89996.0'), 4275101.0)
# (('Weight in kilograms', '2001', '326489.0'), 374722.0)
# (('Weight in kilograms', '2003', '1535.0'), 672.0)
# (('Weight in kilograms', '1992', '4161.0'), 86289.0)
# (('Weight in kilograms', '1993', '14076.0'), 9621.0)
# (('Weight in kilograms', '2005', '1508.0'), 26272.0)
# (('Number of items', '2012', '1120.0'), 3069.0)
# (('Weight in kilograms', '2012', '1858019.0'), 4917968.0)
# (('Weight in kilograms', '2012', '480.0'), 7165.0)
# (('Weight in kilograms', '2007', '2909.0'), 29334.0)
# (('Weight in kilograms', '1999', '3441332.0'), 13679196.0)
# (('Weight in kilograms', '1995', '14199974.0'), 6130162.0)
# (('Weight in kilograms', '1991', '2436613.0'), 20810824.0)
# (('Weight in kilograms', '1995', '393.0'), 6964.0)
# (('Weight in kilograms', '2007', '4769.0'), 31581.0)
# (('Weight in kilograms', '2004', '8812520.0'), 17062589.0)
# (('Weight in kilograms', '2004', '25200.0'), 10584.0)
# (('Weight in kilograms', '2000', '6438077.0'), 1934262.0)
# (('Weight in kilograms', '2004', '148620.0'), 146611.0)
# (('Weight in kilograms', '1997', '2421.0'), 4436.0)
# (('Weight in kilograms', '2010', '112.0'), 1055.0)
# (('Weight in kilograms', '1991', '1572.0'), 22042.0)
# (('Weight in kilograms', '2013', '2056501801.0'), 224753814.0)
# (('Weight in kilograms', '2006', '1554647.0'), 14935956.0)
# (('Weight in kilograms', '1991', '25837964.0'), 10870998.0)
# (('Weight in kilograms', '2009', '2561176.0'), 1578537.0)
# (('Weight in kilograms', '1994', '89658.0'), 1569424.0)
# (('Weight in kilograms', '2008', '2773540.0'), 20305146.0)
# (('Weight in kilograms', '1989', '257.0'), 1810.0)
# (('Weight in kilograms', '1992', '597306.0'), 1417488.0)
# (('Weight in kilograms', '1999', '516331062.0'), 7941886.0)
# (('Weight in kilograms', '2013', '3339490.0'), 11243616.0)
# (('Number of items', '2010', '162581.0'), 928621.0)
# (('Number of pairs', '2016', '10646187.0'), 90737109.0)
# (('Weight in kilograms', '1997', '9244449.0'), 18017200.0)
# (('Weight in kilograms', '1998', '27000.0'), 1683.0)
# (('Weight in kilograms', '1992', '14151.0'), 62280.0)
# (('Number of items', '2000', '1000.0'), 8500.0)
# (('Weight in kilograms', '2003', '2951.0'), 3236.0)
# (('Weight in kilograms', '1996', '113632.0'), 26186.0)
# (('Weight in kilograms', '2011', '86080.0'), 723469.0)
# (('Number of items', '2015', '4.0'), 11586.0)
# (('Weight in kilograms', '2004', '17755.0'), 609075.0)
# (('Weight in kilograms', '2016', '944.0'), 47155.0)
# (('Weight in kilograms', '1990', '25283310.0'), 115612160.0)
# (('Weight in kilograms', '2005', '223800.0'), 2247541.0)
# (('Weight in kilograms', '2010', '2842.0'), 26096.0)
# (('Weight in kilograms', '1996', '47037.0'), 996234.0)
# (('Weight in kilograms', '1993', '46350.0'), 287191.0)
# (('Weight in kilograms', '2012', '4052714.0'), 4219068.0)
# (('Volume in cubic meters', '2007', '64.0'), 6771.0)
# (('Weight in kilograms', '2014', '820383.0'), 6916630.0)
# (('Weight in kilograms', '2006', '2858.0'), 32205.0)
# (('Weight in kilograms', '1991', '8015.0'), 29827.0)
# (('Number of items', '2002', '1170.0'), 3702.0)
# (('Weight in kilograms', '2012', '66600.0'), 196965.0)
# (('Weight in kilograms', '2014', '1625.0'), 13028.0)
# (('Weight in kilograms', '2000', '18109036.0'), 13936144.0)
# (('Weight in kilograms', '2005', '34449289.0'), 30245944.0)
# (('Weight in kilograms', '2001', '16701237.0'), 4912034.0)
# (('Weight in kilograms', '2003', '89901911.0'), 16428689.0)
# (('Weight in kilograms', '2009', '1542.0'), 8802.0)
# (('Weight in kilograms', '2002', '132678.0'), 406298.0)
# (('Weight in kilograms', '2009', '39118436.0'), 34272016.0)
# (('Weight in kilograms', '2003', '20429.0'), 169887.0)
# (('Weight in kilograms', '2010', '3582944.0'), 7718703.0)
# (('Weight in kilograms', '1994', '33899.0'), 33873.0)
# (('Weight in kilograms', '2014', '39034998.0'), 12899795.0)
# (('Weight in kilograms', '2011', '107.0'), 21814.0)
# (('Number of items', '2009', '437.0'), 24470.0)
# (('Weight in kilograms', '2004', '68568.0'), 118960.0)
# (('Weight in kilograms', '2013', '4550020.0'), 14865578.0)
# (('Weight in kilograms', '1993', '297574.0'), 2425299.0)
# (('Weight in kilograms', '1999', '4189.0'), 147456.0)
# (('Weight in kilograms', '1999', '27863.0'), 436559.0)
# (('Weight in kilograms', '2013', '13680.0'), 1095431.0)
# (('Weight in kilograms', '1996', '70.0'), 13.0)
# (('Weight in kilograms', '1989', '5005.0'), 167651.0)
# (('Weight in kilograms', '2010', '408.0'), 5409.0)
# (('Weight in kilograms', '2003', '47.0'), 619.0)
# (('Weight in kilograms', '1995', '552.0'), 28565.0)
# (('Weight in kilograms', '1991', '8402617.0'), 18106272.0)
# (('Weight in kilograms', '2006', '85103.0'), 136728.0)
# (('Weight in kilograms', '1998', '31459.0'), 33974.0)
# (('Weight in kilograms', '2007', '2.0'), 18221.333333333332)
# (('Weight in kilograms', '2016', '1497076.0'), 2946817.0)
# (('Weight in kilograms', '1992', '11729736.0'), 26911004.0)
# (('Weight in kilograms', '1996', '6687.0'), 18192.0)
# (('Weight in kilograms', '2010', '19058.0'), 311101.0)
# (('Weight in kilograms', '2011', '17.0'), 601.0)
# (('Weight in kilograms', '1999', '148359.0'), 458745.0)
# (('Weight in kilograms', '2007', '121384.0'), 92890.0)
# (('Weight in kilograms', '1997', '514504.0'), 5708515.0)
# (('Weight in kilograms', '2011', '6342472.0'), 28333821.0)
# (('Weight in kilograms', '2011', '12438.0'), 50414.0)
# (('Weight in kilograms', '1999', '92003.0'), 198919.0)
# (('Weight in kilograms', '2016', '31969018.0'), 98696141.0)
# (('Weight in kilograms', '1998', '208065.0'), 363592.0)
# (('Weight in kilograms', '1994', '111265.0'), 2606573.0)
# (('Weight in kilograms', '1996', '102226.0'), 1020014.0)
# (('Weight in kilograms', '1992', '1376197.0'), 1048227.0)
# (('Weight in kilograms', '2015', '15000.0'), 23019.0)
# (('Weight in kilograms', '1990', '153745.0'), 287663.0)
# (('Weight in kilograms', '2002', '208004.0'), 76325050.0)
# (('Weight in kilograms', '2012', '1286630.0'), 22826282.0)
# (('Number of items', '2009', '2989.0'), 119101.0)
# (('Weight in kilograms', '2001', '75.0'), 9675.0)
# (('Weight in kilograms', '2010', '345413.0'), 380491.0)
# (('Number of items', '2004', '255866.0'), 7259124.0)
# (('Weight in kilograms', '2011', '57376.0'), 295282.0)
# (('Weight in kilograms', '1992', '37672276.0'), 24531608.0)
# (('Weight in kilograms', '1996', '125748368.0'), 45692304.0)
# (('Weight in kilograms', '2006', '804698.0'), 1482064.0)
# (('Weight in kilograms', '2015', '148856.0'), 105469.0)
# (('Weight in kilograms', '2016', '277820.0'), 852439.0)
# (('Weight in kilograms', '2010', '5029.0'), 22138.0)
# (('Weight in kilograms', '2011', '134.0'), 1206.0)
# (('Weight in kilograms', '1992', '56.0'), 2588.0)
# (('Weight in kilograms', '2016', '309304.0'), 3190748.0)
# (('Weight in kilograms', '2008', '7485.0'), 177454.0)
# (('Weight in kilograms', '1993', '200329.0'), 1223764.0)
# (('Weight in kilograms', '2012', '3421.0'), 352923.0)
# (('Weight in kilograms', '2014', '1520127.0'), 25733874.0)
# (('Weight in kilograms', '1999', '177750.0'), 5443387.0)
# (('Weight in kilograms', '1992', '42.0'), 2197.0)
# (('Number of items', '2010', '361474320.0'), 23442248.0)
# (('Weight in kilograms', '2010', '2212203.0'), 5895504.0)
# (('Weight in kilograms', '2007', '1442460.0'), 925582.0)
# (('Weight in kilograms', '1993', '187400544.0'), 2706752.0)
# (('Weight in kilograms', '2005', '640000.0'), 287889.0)
# (('Weight in kilograms', '2009', '300.0'), 2872.0)
# (('Weight in kilograms', '2003', '3639859.0'), 2497725.0)
# (('Weight in kilograms', '2000', '45209.0'), 638626.0)
# (('Weight in kilograms', '2003', '26824.0'), 63388.0)
# (('Weight in kilograms', '2005', '86715.0'), 15833.0)
# (('Weight in kilograms', '1992', '2433498.0'), 7610127.0)
# (('Weight in kilograms', '1994', '2538.0'), 17171.0)
# (('Number of items', '2008', '132549.0'), 2424699.0)
# (('Weight in kilograms', '1992', '85372.0'), 517342.0)
# (('Weight in kilograms', '2010', '67039.0'), 318860.0)
# (('Weight in kilograms', '2007', '2323442.0'), 4122829.0)
# (('Weight in kilograms', '2008', '38551.0'), 511759.0)
# (('Weight in kilograms', '2011', '406262.0'), 3311340.0)
# (('Weight in kilograms', '2010', '2302933.0'), 12838573.0)
# (('Weight in kilograms', '2000', '1909027.0'), 5131539.0)
# (('Weight in kilograms', '2008', '14640.0'), 41261.0)
# (('Weight in kilograms', '2005', '6974768.0'), 2845423.0)
# (('Weight in kilograms', '1995', '681724544.0'), 1214690048.0)
# (('Weight in kilograms', '2005', '1756.0'), 28208.0)
# (('Weight in kilograms', '2010', '3086469.0'), 37838631.0)
# (('Weight in kilograms', '2001', '78533502.0'), 27694549.0)
# (('Weight in kilograms', '1995', '25300.0'), 13889.0)
# (('Weight in kilograms', '2000', '907979.0'), 3217894.0)
# (('Weight in kilograms', '2015', '12854.0'), 169475.0)
# (('Weight in kilograms', '1991', '10062.0'), 96349.0)
# (('Weight in kilograms', '2003', '72300.0'), 28425.0)
# (('Volume in cubic meters', '2015', '21441.0'), 2168533.0)
# (('Weight in kilograms', '1999', '94452159.0'), 131804832.0)
# (('Weight in kilograms', '1995', '134990.0'), 484936.0)
# (('Number of items', '2003', '16756.0'), 302195352.0)
# (('Weight in kilograms', '1990', '110642.0'), 1777205.0)
# (('Weight in kilograms', '1998', '62.0'), 2129.0)
# (('Weight in kilograms', '1989', '395424.0'), 457294.0)
# (('Weight in kilograms', '2003', '9958008.0'), 3030945.0)
# (('Weight in kilograms', '2000', '11712.0'), 70180.0)
# (('Weight in kilograms', '2006', '1605089.0'), 4355475.0)
# (('Number of items', '2003', '899669.0'), 7164317.0)
# (('Weight in kilograms', '2002', '388.0'), 1382.0)
# ...
# (('Weight in kilograms', '2013', '11278.0'), 64087.0)
# (('Weight in kilograms', '2004', '120607.0'), 543820.0)
# (('Weight in kilograms', '1997', '191978.0'), 1259375.0)
# (('Weight in kilograms', '1998', '2199.0'), 11076.0)
# (('Weight in kilograms', '1990', '2812.0'), 47190.0)
# (('Weight in carats', '2004', '150800.0'), 169292.0)
# (('Weight in kilograms', '1989', '218262.0'), 1229928.0)
# (('Weight in kilograms', '2015', '10585.0'), 96600.0)
# (('Weight in kilograms', '1989', '50386.0'), 24688.0)
# (('Weight in kilograms', '1995', '640.0'), 5268.0)
# (('Weight in kilograms', '1996', '4364303872.0'), 977372992.0)
# (('Weight in kilograms', '2016', '5920286.0'), 32325001.0)
# (('Weight in kilograms', '1997', '493.0'), 10878.0)
# (('Weight in kilograms', '2010', '882653.0'), 860453.0)
# (('Area in square metres', '2008', '79740802.0'), 344556949.0)
# (('Weight in kilograms', '2014', '573580.0'), 1404300.0)
# (('Weight in kilograms', '1990', '4626702.0'), 4013808.0)
# (('Weight in kilograms', '2015', '300.0'), 71379.0)
# (('Weight in kilograms', '1998', '2176966.0'), 7214016.0)
# (('Weight in kilograms', '2002', '59688.0'), 206608.0)
# (('Weight in kilograms', '2010', '10175150.0'), 24880794.0)
# (('Number of items', '2007', '13028824.0'), 547539255.0)
# (('Weight in kilograms', '1989', '469630.0'), 1554288.0)
# (('Number of items', '2003', '4477.0'), 55702.0)
# (('Weight in kilograms', '2003', '980.0'), 1916.0)
# (('Weight in kilograms', '1994', '617519.0'), 2488709.0)
# (('Weight in kilograms', '2011', '372524.0'), 2361648.0)
# (('Weight in kilograms', '1997', '1421591.0'), 739259.0)
# (('Weight in kilograms', '2005', '122905.0'), 2555224.0)
# (('Weight in kilograms', '1989', '8037217.0'), 3221039.0)
# (('Weight in kilograms', '2012', '77.0'), 2936.0)
# (('Weight in kilograms', '1999', '60.0'), 117.0)
# (('Number of items', '2014', '108.0'), 29621.0)
# (('Weight in kilograms', '2000', '6571.0'), 137887.0)
# (('Weight in kilograms', '1991', '30.0'), 531.0)
# (('Weight in kilograms', '2005', '19501.0'), 50744.0)
# (('Weight in kilograms', '2013', '613410.0'), 2417338.0)
# (('Weight in kilograms', '2012', '9228287.0'), 33146109.0)
# (('Weight in kilograms', '1995', '150342.0'), 2538065.0)
# (('Number of items', '2001', '2872645.0'), 2498410.0)
# (('Weight in kilograms', '1999', '12546.0'), 51314.0)
# (('Weight in kilograms', '2008', '3494.0'), 62586.0)
# (('Number of items', '2015', '290.0'), 51233.0)
# (('Number of items', '2011', '376182847.0'), 86843854.0)
# (('Weight in kilograms', '2010', '218226.0'), 1583081.0)
# (('Number of items', '2009', '35.0'), 13096.0)
# (('Weight in kilograms', '1999', '308185.0'), 498011.0)
# (('Weight in kilograms', '1998', '4138000.0'), 5805777.0)
# (('Weight in kilograms', '1992', '11955055.0'), 28436472.0)
# (('Weight in kilograms', '1993', '8439.0'), 22569.0)
# (('Weight in kilograms', '2009', '3010.0'), 120811.0)
# (('Weight in kilograms', '1998', '14201584.0'), 59567344.0)
# (('Weight in kilograms', '1992', '69445.0'), 146100.0)
# (('Number of items', '2002', '89.0'), 99959.0)
# (('Number of items', '2009', '2986.0'), 1384705.0)
# (('Weight in kilograms', '2002', '5607792.0'), 10586183.0)
# (('Weight in kilograms', '1993', '597.0'), 1689.0)
# (('Area in square metres', '2005', '32694.0'), 231892.0)
# (('Weight in kilograms', '2002', '81329.0'), 395770.0)
# (('Weight in kilograms', '2007', '2169252.0'), 4604991.0)
# (('Weight in kilograms', '1992', '175073.0'), 152197.0)
# (('Weight in kilograms', '2001', '455490.0'), 1105185.0)
# (('Weight in kilograms', '1998', '141080.0'), 385197.0)
# (('Weight in kilograms', '1997', '40829.0'), 399246.0)
# (('Weight in kilograms', '1993', '1935.0'), 21515936.0)
# (('Weight in kilograms', '1990', '34194.0'), 479592.0)
# (('Weight in kilograms', '2009', '9884391.0'), 11792320.0)
# (('Number of items', '2000', '284364.0'), 1455473.0)
# (('Weight in kilograms', '2007', '7289552.0'), 6465831.0)
# (('Weight in kilograms', '1991', '11108.0'), 130517.0)
# (('Area in square metres', '2003', '40047.0'), 218313.0)
# (('Weight in kilograms', '2002', '5723975886.0'), 982293376.0)
# (('Weight in kilograms', '1991', '274791.0'), 1024288.0)
# (('Weight in kilograms', '2006', '248973.0'), 316421.0)
# (('Weight in kilograms', '1997', '132.0'), 1071.0)
# (('Weight in kilograms', '2016', '809095.0'), 13883201.0)
# (('Weight in kilograms', '1991', '68392.0'), 349628.0)
# (('Weight in kilograms', '2002', '21926981.0'), 24756821.0)
# (('Weight in kilograms', '2000', '460383.0'), 7455279.0)
# (('Weight in kilograms', '2014', '5887395.0'), 44306524.0)
# (('Weight in kilograms', '2005', '1519.0'), 12294.0)
# (('Weight in kilograms', '1994', '445.0'), 5132.0)
# (('Weight in kilograms', '2012', '37671739.0'), 68621945.0)
# (('Weight in kilograms', '1995', '17459022.0'), 11828942.0)
# (('Volume in cubic meters', '2003', '37334.0'), 104769.0)
# (('Weight in kilograms', '2010', '3477735.0'), 5218967.0)
# (('Weight in kilograms', '2006', '43778.0'), 64361.0)
# (('Weight in kilograms', '2014', '8340985.0'), 25323944.0)
# (('Weight in kilograms', '2005', '1904144.0'), 34713631.0)
# (('Weight in kilograms', '2012', '867747.0'), 2023324.0)
# (('Weight in kilograms', '2008', '4579.0'), 188707.0)
# (('Number of items', '2013', '21.0'), 7791.0)
# (('Weight in kilograms', '2001', '7110793.0'), 13480376.0)
# (('Weight in kilograms', '2003', '6310.0'), 600.0)
# (('Weight in kilograms', '2011', '70010221.0'), 195020301.0)
# (('Weight in kilograms', '1990', '796692.0'), 469158.0)
# (('Weight in kilograms', '1996', '6882362.0'), 37406132.0)
# (('Weight in kilograms', '1990', '1394618.0'), 4159580.0)
# (('Weight in kilograms', '2005', '28716.0'), 296164.0)
# (('Weight in kilograms', '2006', '2329.0'), 52058.0)
# (('Weight in kilograms', '1992', '2435976.0'), 4349909.0)
# (('Weight in kilograms', '2014', '163765.0'), 559478.0)
# (('Weight in kilograms', '1999', '331754.0'), 2878530.0)
# (('Weight in kilograms', '2012', '507532.0'), 2450486.0)
# (('Weight in kilograms', '2015', '4447.0'), 255148.0)
# (('Weight in kilograms', '2010', '744773628.0'), 14935980.0)
# (('Weight in kilograms', '2005', '429618.0'), 1892391.0)
# (('Number of items', '2011', '20.0'), 200.0)
# (('Weight in kilograms', '1995', '1832.0'), 40388.0)
# (('Weight in kilograms', '2013', '4526993.0'), 3503135.0)
# (('Weight in kilograms', '1990', '542501.0'), 226067.0)
# (('Weight in kilograms', '2008', '15.0'), 109.0)
# (('Weight in kilograms', '2001', '184547.0'), 268798.0)
# (('Weight in kilograms', '1996', '6483.0'), 893291.0)
# (('Number of items', '2002', '54766.0'), 184625.0)
# (('Weight in kilograms', '2011', '496871.0'), 1883822.0)
# (('Weight in kilograms', '1989', '110355.0'), 416188.0)
# (('Weight in kilograms', '2002', '51945406.0'), 19747320.0)
# (('Weight in kilograms', '2014', '3323.0'), 137043.0)
# (('Weight in kilograms', '2002', '63500.0'), 16682.0)
# (('Weight in kilograms', '1991', '189001.0'), 197707.0)
# (('Weight in kilograms', '2001', '18711.0'), 175162.0)
# (('Weight in kilograms', '2014', '391753.0'), 296533.0)
# (('Area in square metres', '2011', '2.0'), 68.0)
# (('Weight in kilograms', '1999', '13234.0'), 424669.0)
# (('Number of items', '2012', '3894.0'), 4618.0)
# (('Weight in kilograms', '1992', '91.0'), 5148.0)
# (('Weight in kilograms', '1989', '13070407.0'), 547472.0)
# (('Weight in kilograms', '1998', '1508501.0'), 2669698.0)
# (('Weight in kilograms', '2007', '238151139.0'), 140751435.0)
# (('Weight in kilograms', '2000', '1688593.0'), 1308043.0)
# (('Weight in kilograms', '1993', '280831.0'), 189742.0)
# (('Weight in kilograms', '2010', '80305886.0'), 137568102.0)
# (('Weight in kilograms', '1992', '253983.0'), 239657.0)
# (('Weight in kilograms', '2002', '3750.0'), 2810.0)
# (('Weight in kilograms', '1996', '853870.0'), 1795756.0)
# (('Weight in kilograms', '1989', '55906.0'), 125424.0)
# (('Weight in kilograms', '2002', '526037.0'), 187378.0)
# (('Weight in kilograms', '2014', '90414.0'), 319826.0)
# (('Weight in kilograms', '2006', '59634.0'), 1196343.0)
# (('Number of items', '2011', '524.0'), 7831.0)
# (('Weight in kilograms', '2016', '1309.0'), 11932.0)
# (('Weight in kilograms', '1997', '4934490.0'), 8901686.0)
# (('Weight in kilograms', '2009', '12252990082.0'), 4592650648.0)
# (('Weight in kilograms', '1992', '23164.0'), 314723.0)
# (('Weight in kilograms', '2007', '398.0'), 1486.0)
# (('Weight in kilograms', '2003', '215864.0'), 630364.0)
# (('Weight in kilograms', '2011', '42.0'), 124.0)
# (('Weight in kilograms', '2015', '42.0'), 4651.0)
# (('Weight in kilograms', '2012', '1683285.0'), 2816946.0)
# (('Weight in kilograms', '2003', '454.0'), 1225.0)
# (('Weight in kilograms', '2011', '589989.0'), 4369898.0)
# (('Weight in kilograms', '1997', '1429172.0'), 1981661.0)
# (('Number of items', '2002', '2797.0'), 27669.0)
# (('Weight in kilograms', '2007', '1367805.0'), 4807388.0)
# (('Number of items', '2008', '736469.0'), 6235072.0)
# (('Volume in litres', '1999', '18577.0'), 111.0)
# (('Weight in kilograms', '1996', '22500.0'), 1703820.0)
# (('Weight in kilograms', '2002', '4828518.0'), 2372677.0)
# (('Weight in kilograms', '1990', '252303.0'), 141806.0)
# (('Weight in kilograms', '2015', '1490242.0'), 1313231.0)
# (('Weight in kilograms', '2009', '4740225.0'), 2304235.0)
# (('Weight in kilograms', '1992', '19899008.0'), 57837860.0)
# (('Weight in kilograms', '1993', '2554.0'), 39989.0)
# (('Weight in kilograms', '1991', '448681.0'), 1981839.0)
# (('Weight in kilograms', '2011', '616646.0'), 1982905.0)
# (('Weight in kilograms', '2000', '15169.0'), 854282.0)
# (('Weight in kilograms', '1989', '1000.0'), 310.0)
# (('Weight in kilograms', '1995', '1681368.0'), 5321780.0)
# (('Weight in kilograms', '1997', '180597.0'), 979481.0)
# (('Number of items', '2000', '3190293.0'), 149780004.0)
# (('Weight in kilograms', '2003', '297339.0'), 2272790.0)
# (('Weight in kilograms', '2009', '26535.0'), 704585.0)
# (('Number of items', '2006', '1691.0'), 24174.0)
# (('Weight in kilograms', '2002', '362.0'), 5542.0)
# (('Weight in kilograms', '1995', '153158.0'), 73733.0)
# (('Weight in kilograms', '1990', '17010.0'), 206111.0)
# (('Weight in kilograms', '1997', '15410.0'), 143750.0)
# (('Number of items', '2006', '20389.0'), 8974725.0)
# (('Weight in kilograms', '1995', '678610.0'), 791621.0)
# (('Weight in kilograms', '2001', '144036.0'), 231905.0)
# (('Weight in kilograms', '1991', '718.0'), 10763.0)
# (('Volume in litres', '1995', '107118168.0'), 68196928.0)
# (('Weight in kilograms', '1993', '16248099.0'), 8307038.0)
# (('Weight in kilograms', '1994', '4621758.0'), 9995419.0)
# (('Number of pairs', '2015', '64042.0'), 740021.0)
# (('Weight in kilograms', '1994', '53675.0'), 514452.0)
# (('Weight in kilograms', '1996', '282120.0'), 1518027.0)
# (('Number of items', '2005', '3800.0'), 60692467.0)
# (('Weight in kilograms', '1995', '3927.0'), 42893.0)
# (('Weight in kilograms', '1992', '110117.0'), 22409.0)
# (('Volume in litres', '2016', '74544.0'), 141763.0)
# (('Weight in kilograms', '2011', '9774576.0'), 12550255.0)
# (('Weight in kilograms', '2008', '12780509.0'), 8911914.0)
# (('Weight in kilograms', '2007', '53722515.0'), 118070017.0)
# (('Weight in kilograms', '1994', '740189.0'), 738525.0)
# (('Weight in kilograms', '2004', '441.0'), 439.0)
# (('Weight in kilograms', '2002', '246163.0'), 39267.0)
# (('Weight in kilograms', '1992', '382430.0'), 151795.0)
# (('Number of items', '2011', '1018.0'), 36070.0)
# (('Number of pairs', '2010', '710.0'), 2923.0)
# (('Weight in kilograms', '2011', '9.0'), 194209.0)
# (('Weight in kilograms', '2013', '96374.0'), 311750.0)
# (('Weight in kilograms', '2010', '21442.0'), 77258.0)
# (('Weight in kilograms', '2005', '2527.0'), 165982.0)
# (('Weight in kilograms', '2016', '64657550.0'), 1331514767.0)
# (('Weight in kilograms', '1992', '3836.0'), 2337.0)
# (('Weight in kilograms', '1995', '541125.0'), 1723950.0)
# (('Weight in kilograms', '2012', '1035689.0'), 2521450.0)
# (('Number of items', '2008', '13328.0'), 115295.0)
# (('Weight in kilograms', '2007', '1090.0'), 4518.0)
# (('Weight in kilograms', '2010', '145310.0'), 86970.0)
# (('Weight in kilograms', '2000', '106100.0'), 91508.0)
# (('Weight in kilograms', '2007', '147087.0'), 217501.0)
# (('Weight in kilograms', '1989', '92315952.0'), 54315024.0)
# (('Weight in kilograms', '2014', '47945.0'), 285265.0)
# (('Weight in kilograms', '2011', '6512.0'), 216360.0)
# (('Weight in kilograms', '2015', '3413295.0'), 6420342.0)
# (('Weight in kilograms', '2000', '440752.0'), 2744108.0)
# (('Weight in kilograms', '2005', '9502.0'), 50686.0)
# (('Weight in kilograms', '2012', '1451482.0'), 7559414.0)
# (('Weight in kilograms', '2011', '112807.0'), 550149.0)
# (('Weight in kilograms', '1999', '11371348.0'), 4152617.0)
# (('Weight in kilograms', '1991', '4447451.0'), 6570143.0)
# (('Weight in kilograms', '1991', '28.0'), 1799.0)
# (('Weight in kilograms', '2005', '46820.0'), 118255.0)
# (('Weight in kilograms', '2015', '4.0'), 7.0)
# (('Weight in kilograms', '1995', '11261873.0'), 13833271.0)
# (('Weight in kilograms', '1998', '285116.0'), 116491.0)
# (('Weight in kilograms', '1996', '198547.0'), 775958.0)
# (('Weight in kilograms', '1996', '671985024.0'), 56933096.0)
# (('Weight in kilograms', '1992', '16529.0'), 54911.0)
# (('Weight in kilograms', '1989', '1458757.0'), 2398090.0)
# (('Weight in kilograms', '2000', '967022.0'), 203057.0)
# (('Weight in kilograms', '1989', '477614.0'), 1307158.0)
# (('Weight in kilograms', '2004', '2797.0'), 20613.0)
# (('Weight in kilograms', '1996', '19.0'), 205762.0)
# (('Weight in kilograms', '2000', '767797.0'), 8493116.0)
# (('Weight in kilograms', '1998', '1363187.0'), 2395046.0)
# (('Weight in kilograms', '2002', '3991952.0'), 11477420.0)
# (('Weight in kilograms', '2008', '90758348.0'), 33409353.0)
# (('Weight in kilograms', '1997', '13125.0'), 117901.0)
# (('Weight in kilograms', '2013', '9619830.0'), 6329691.0)
# (('Weight in kilograms', '2016', '2765583.0'), 4917903.0)
# (('Weight in kilograms', '1994', '53395856.0'), 62015176.0)
# (('Weight in kilograms', '2005', '103417.0'), 642049.0)
# (('Volume in litres', '1990', '182865.0'), 67000.0)
# (('Weight in kilograms', '1992', '5693.0'), 332660.0)
# (('Weight in kilograms', '2007', '386.0'), 13771.0)
# (('Weight in kilograms', '2014', '1347557.0'), 8740156.0)
# (('Weight in kilograms', '2015', '91427.0'), 428544.0)
# (('Weight in kilograms', '1999', '5270.0'), 25282.0)
# (('Number of items', '2007', '8927.0'), 95343.0)
# (('Volume in litres', '2000', '3036681.0'), 3377687.0)
# (('Weight in kilograms', '2003', '128913.0'), 929978.0)
# (('Volume in cubic meters', '2012', '14684.0'), 5016917.0)
# (('Weight in kilograms', '2012', '61793.0'), 879581.0)
# (('Weight in kilograms', '1990', '1907598.0'), 5510613.0)
# (('Weight in kilograms', '1991', '132104.0'), 542003.0)
# (('Weight in kilograms', '1991', '87543.0'), 786349.0)
# (('Weight in kilograms', '2010', '3564739.0'), 2866853.0)
# (('Weight in kilograms', '1993', '721595.0'), 1395695.0)
# (('Weight in kilograms', '2006', '2501768.0'), 15039522.0)
# (('Weight in kilograms', '2000', '1675.0'), 18771.0)
# (('Number of items', '2009', '671.0'), 398430.0)
# (('Weight in kilograms', '1998', '12782340.0'), 9710333.0)
# (('Weight in kilograms', '2012', '229095.0'), 578722.0)
# (('Weight in kilograms', '1995', '4603.0'), 39769.0)
# (('Weight in kilograms', '2010', '54383.0'), 440927.0)
# (('Weight in kilograms', '2001', '305721.0'), 54501.0)
# (('Weight in kilograms', '2008', '1733.0'), 41667.0)
# (('Weight in kilograms', '2011', '1936353.0'), 9949594.0)
# (('Weight in kilograms', '1997', '1782336.0'), 4425791.0)
# (('Weight in kilograms', '2001', '170205.0'), 55272.0)
# (('Weight in kilograms', '1990', '723.0'), 39210.0)
# (('Weight in kilograms', '2001', '7.0'), 200.0)
# (('Number of items', '2005', '67.0'), 1347733190.0)
# (('Weight in kilograms', '2002', '45185.0'), 113347.0)
# (('Weight in kilograms', '1999', '102402.0'), 522201.0)
# (('Weight in kilograms', '2011', '17709.0'), 1182210.0)
# (('Weight in kilograms', '2006', '1344120.0'), 712962.0)
# (('Weight in kilograms', '2002', '1952900.0'), 9057383.0)
# (('Length in metres', '2001', '16314611.0'), 26703735.0)
# (('Weight in kilograms', '2008', '64975.0'), 65755.0)
# (('Weight in kilograms', '1989', '17908.0'), 145483.0)
# (('Weight in kilograms', '2010', '185.0'), 6622.0)
# (('Weight in kilograms', '2006', '24.0'), 732.0)
# (('Weight in kilograms', '1997', '11806.0'), 2541120.0)
# (('Weight in kilograms', '1989', '2625.0'), 6733.0)

# %% [markdown]
# # Problema 5: O preço máximo, mínimo e médio por tipo de unidade e ano

# %%
# Processar o conjunto de dados
transacoes = dataset.map(lambda linha: ((linha.split(";")[7], linha.split(";")[1]), float(linha.split(";")[5].replace(",", ".")) if linha.split(";")[5].replace(",", ".").replace(".", "").isdigit() else 0))

# Filtrar transações com preços inválidos
transacoes_validas = transacoes.filter(lambda transacao: transacao[1] != 0)

# Calcular preço máximo, mínimo e médio por tipo de unidade e ano
estatisticas_preco_por_unidade_ano = transacoes_validas.aggregateByKey(
    (float('-inf'), float('inf'), 0.0, 0),
    lambda a, b: (max(a[0], b), min(a[1], b), a[2] + b, a[3] + 1),
    lambda a, b: (max(a[0], b[0]), min(a[1], b[1]), a[2] + b[2], a[3] + b[3])
)

# Calcular preço médio da transação
preco_medio_por_unidade_ano = estatisticas_preco_por_unidade_ano.mapValues(lambda v: (v[0], v[1], v[2] / v[3]))

# Iterar sobre os resultados e imprimir preço máximo, mínimo e médio por tipo de unidade e ano
for (unidade_ano, (preco_maximo, preco_minimo, preco_medio)) in preco_medio_por_unidade_ano.collect():
    tipo_unidade, ano = unidade_ano
    print("Tipo de Unidade:", tipo_unidade)
    print("Ano:", ano)
    print("Preço Máximo:", preco_maximo)
#
# Tipo de Unidade: Electrical energy in thousands of kilowatt-hours
# Ano: 2003
# Preço Máximo: 444649689.0
# Preço Mínimo: 7981734.0
# Preço Médio: 123333141.14285715
#
# Tipo de Unidade: Thousands of items
# Ano: 2009
# Preço Máximo: 26547252.0
# Preço Mínimo: 347.0
# Preço Médio: 4747403.52631579
#
# Tipo de Unidade: Thousands of items
# Ano: 2000
# Preço Máximo: 13355885.0
# Preço Mínimo: 1561.0
# Preço Médio: 2061303.5
#
# Tipo de Unidade: Electrical energy in thousands of kilowatt-hours
# Ano: 2002
# Preço Máximo: 346063564.0
# Preço Mínimo: 41605.0
# Preço Médio: 125865769.75
#
# Tipo de Unidade: Electrical energy in thousands of kilowatt-hours
# Ano: 2012
# Preço Máximo: 3314846568.0
# Preço Mínimo: 2148.0
# Preço Médio: 598947956.5714285
#
# Tipo de Unidade: Electrical energy in thousands of kilowatt-hours
# Ano: 2013
# Preço Máximo: 2938885430.0
# Preço Mínimo: 79.0
# Preço Médio: 877632325.5454545
#
# Tipo de Unidade: Electrical energy in thousands of kilowatt-hours
# Ano: 1991
# Preço Máximo: 2515.0
# Preço Mínimo: 2515.0
# Preço Médio: 2515.0
#
# Tipo de Unidade: Electrical energy in thousands of kilowatt-hours
# Ano: 2016
# Preço Máximo: 1065282687.0
# Preço Mínimo: 1128262.0
# Preço Médio: 233217751.375

# %% [markdown]
# # Problema 6: O país com o maior preço médio de commodities na categoria Exportação

# %%
# Filtra o conjunto de dados para a categoria de exportação
exportacao = dataset.filter(lambda line: line.split(";")[4] == "Export")

# Mapeia cada linha para pares chave-valor (país, preço)
preco_por_pais = exportacao.map(lambda line: (line.split(";")[0], float(line.split(";")[5])))

# Calcula a soma e contagem dos preços para cada país
soma_contagem_por_pais = preco_por_pais.aggregateByKey(
    (0.0, 0),
    lambda acc, price: (acc[0] + price, acc[1] + 1),
    lambda acc1, acc2: (acc1[0] + acc2[0], acc1[1] + acc2[1])
)

# Calcula o preço médio para cada país
preco_medio_por_pais = soma_contagem_por_pais.mapValues(lambda acc: acc[0] / acc[1])

# Encontra o país com o maior preço médio
pais_com_maior_preco_medio = preco_medio_por_pais.max(lambda x: x[1])

# Imprime o resultado
print("País com o maior preço médio de commodities na categoria Exportação:",
      pais_com_maior_preco_medio[0], pais_com_maior_preco_medio[1])
# Out:
# País com o maior preço médio de commodities na categoria Exportação: Angola 16369666068.142857

# %% [markdown]
# # Problema 7: A commodity mais comercializada (somando as quantidades) em 2016 por tipo de fluxo

# %%
# Filtra o conjunto de dados para o ano de 2016
commodities_2016 = dataset.filter(lambda line: line.split(";")[1] == "2016")

# Mapeia cada linha para pares chave-valor ((commodity, tipo de fluxo), quantidade)
quantidades_commodities_2016 = commodities_2016.map(lambda line: ((line.split(";")[3], line.split(";")[4]), float(line.split(";")[8])))

# Calcula a soma das quantidades para cada commodity e tipo de fluxo
quantidades_commodities_fluxo = quantidades_commodities_2016.reduceByKey(lambda a, b: a + b)

# Encontra a commodity mais comercializada em 2016
commodity_mais_comercializada = quantidades_commodities_fluxo.max(key=lambda x: x[1])

# Imprime o resultado
print("Commodity mais comercializada em 2016:", commodity_mais_comercializada[0])
# Out:
# Commodity mais comercializada em 2016: ('Iron ore, concentrate, not iron pyrites,unagglomerate', 'Export')
